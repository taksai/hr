# %%
import matplotlib
import numpy as np
import pandas as pd
import sys
# sys.path.append("this\is\the\path")
import urllib.request
from time import sleep

# %%
df = pd.read_csv("query_result.csv")
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (30,40,198,208,239,249,280,290,321,331,362,372) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250806 entries, 0 to 250805
# Columns: 390 entries, Year to Created
# dtypes: float64(74), int64(152), object(164)
# memory usage: 746.3+ MB

# %%
df_temp = df.head().T
df_temp
# Out:
#                                                               0  \
# Year                                                       2013
# MonthDay                                                    105
# JyoCD                                                         6
# Kaiji                                                         1
# Nichiji                                                       1
# RaceNum                                                       1
# Wakuban                                                       1
# WakubanInsideNum                                        Inside1
# Umaban                                                        1
# RacesHassoTimeDatetime                      2013-01-05 09:50:00
# UmaDataKubun                                                  7
# UmaBamei                                                  トドロック
# UmaNameSex                                                    牡
# UmaNameTozai                                                 関東
# ...

# %%
df_temp.to_csv("column_list.csv", encoding="sjis")

# %%
#入力ファイル名
filename = './KYI_2016/KYI160105.txt'

#ファイルの区切り位置の定義
colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,10),(10,18),(18,54),(54,59),(59,64),(64,69),(69,74),(74,79),(79,84),(84,89),(89,90),(90,91),(91,92),(92,95),(95,100),(100,102),(102,107),(107,109),(109,112),(112,115),(115,118),(118,121),(121,124),(124,127),(127,130),(130,133),(133,136),(136,139),(139,144),(144,149),(149,154),(154,155),(155,156),(156,160),(160,163),(163,165),(165,166),(166,168),(168,170),(170,171),(171,183),(183,186),(186,187),(187,199),(199,203),(203,219),(219,235),(235,251),(251,267),(267,283),(283,291),(291,299),(299,307),(307,315),(315,323),(323,324),(324,326),(326,327),(327,328),(328,329),(329,330),(330,331),(331,332),(332,333),(333,334),(334,335),(335,340),(340,345),(345,346),(346,352),(352,357),(357,358),(358,363),(363,368),(368,373),(373,378),(378,379),(379,381),(381,383),(383,384),(384,386),(386,388),(388,389),(389,391),(391,393),(393,394),(394,395),(395,396),(396,399),(399,402),(402,403),(403,404),(404,444),(444,446),(446,448),(448,450),(450,452),(452,454),(454,456),(456,458),(458,460),(460,464),(464,468),(468,469),(469,477),(477,501),(501,504),(504,507),(507,510),(510,513),(513,516),(516,519),(519,523),(523,527),(527,529),(529,534),(534,537),(537,538),(538,539),(539,541),(541,543),(543,559),(559,561),(561,569),(569,572),(572,622),(622,623),(623,624),(624,1022)]

#ファイルを区切った際のカラム名
names = ['場コード','年','回','日','Ｒ','馬番','血統登録番号','馬名','ＩＤＭ','騎手指数','情報指数','予備１','予備２','予備３','総合指数','脚質','距離適性','上昇度','ローテーション','基準オッズ','基準人気順位','基準複勝オッズ','基準複勝人気順位','特定情報◎','特定情報○','特定情報▲','特定情報△','特定情報×','総合情報◎','総合情報○','総合情報▲','総合情報△','総合情報×','人気指数','調教指数','厩舎指数','調教矢印コード','厩舎評価コード','騎手期待連対率','激走指数','蹄コード','重適正コード','クラスコード','予備','ブリンカー','騎手名','負担重量','見習い区分','調教師名','調教師所属','前走１競走成績キー','前走２競走成績キー','前走３競走成績キー','前走４競走成績キー','前走５競走成績キー','前走１レースキー','前走２レースキー','前走３レースキー','前走４レースキー','前走５レースキー','枠番','予備','総合印','ＩＤＭ印','情報印','騎手印','厩舎印','調教印','激走印','芝適性コード','ダ適性コード','騎手コード','調教師コード','予備','獲得賞金','収得賞金','条件クラス','テン指数','ペース指数','上がり指数','位置指数','ペース予想','道中順位','道中差','道中内外','後３Ｆ順位','後３Ｆ差','後３Ｆ内外','ゴール順位','ゴール差','ゴール内外','展開記号','距離適性２','枠確定馬体重','枠確定馬体重増減','取消フラグ','性別コード','馬主名','馬主会コード','馬記号コード','激走順位','LS指数順位','テン指数順位','ペース指数順位','上がり指数順位','位置指数順位','騎手期待単勝率','騎手期待３着内率','輸送区分','走法','体型','体型総合１','体型総合２','体型総合３','馬特記１','馬特記２','馬特記３','馬スタート指数','馬出遅率','参考前走','参考前走騎手コード','万券指数','万券印','降級フラグ','激走タイプ','休養理由分類コード','フラグ','入厩何走目','入厩年月日','入厩何日前','放牧先','放牧先ランク','厩舎ランク','予備']
         

# df = pd.read_fwf(filename,colspecs=colspecs,names=names,converters={'key':np.str},encoding="cp932")
df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:741: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)

# %%
df.to_csv("KYI160105.csv", encoding="cp932")

# %%
# create a password manager
password_mgr = urllib.request.HTTPPasswordMgrWithDefaultRealm()

# Add the username and password.
# If we knew the realm, we could use it instead of None.
username=18075520
password=46027091

top_level_url = "http://www.jrdb.com/member/"
password_mgr.add_password(None, top_level_url, username, password)

handler = urllib.request.HTTPBasicAuthHandler(password_mgr)

# create "opener" (OpenerDirector instance)
opener = urllib.request.build_opener(handler)

# use the opener to fetch a URL
# opener.open("http://www.jrdb.com/member/datazip/Kyi/2018/KYI180722.zip")

# Install the opener.
# Now all calls to urllib.request.urlopen use our opener.
urllib.request.install_opener(opener)

# %%
#URLと保存パスを指定
for i in range(17, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                l = "BAC" + str(i) + str(j).zfill(2) + str(k).zfill(2) 
                print(l)

                url = "http://www.jrdb.com/member/datazip/Bac/20" + str(i) + "/" + l + ".zip"
                savename = "./BAC/" + l  + ".zip"

                #ダウンロード --- （＊１）
                nem = urllib.request.urlopen(url).read()

                #ファイルへ保存 --- （＊２）
                with open(savename, mode="wb") as f:
                    f.write(nem)
                    print("保存しました") 
            except:
                pass
            sleep(0.3)
# http://www.jrdb.com/member/datazip/Kyi/2016/KYI160105.zip
# Out:
# BAC170101
# BAC170102
# BAC170103
# BAC170104
# BAC170105
# 保存しました
# BAC170106
# BAC170107
# 保存しました
# BAC170108
# 保存しました
# BAC170109
# BAC170110
# BAC170111
# BAC170112
# BAC170113
# BAC170114
# 保存しました
# BAC170115
# 保存しました
# BAC170116
# 保存しました
# BAC170117
# 保存しました
# BAC170118
# BAC170119
# BAC170120
# BAC170121
# 保存しました
# BAC170122
# 保存しました
# BAC170123
# BAC170124
# BAC170125
# BAC170126
# BAC170127
# BAC170128
# 保存しました
# BAC170129
# 保存しました
# BAC170130
# BAC170131
# BAC170201
# BAC170202
# BAC170203
# BAC170204
# 保存しました
# BAC170205
# 保存しました
# BAC170206
# BAC170207
# BAC170208
# BAC170209
# BAC170210
# BAC170211
# 保存しました
# BAC170212
# 保存しました
# BAC170213
# 保存しました
# BAC170214
# BAC170215
# BAC170216
# BAC170217
# BAC170218
# 保存しました
# BAC170219
# 保存しました
# BAC170220
# BAC170221
# BAC170222
# BAC170223
# BAC170224
# BAC170225
# 保存しました
# BAC170226
# 保存しました
# BAC170227
# BAC170228
# BAC170229
# BAC170230
# BAC170231
# BAC170301
# BAC170302
# BAC170303
# BAC170304
# 保存しました
# BAC170305
# ...

# %%
#URLと保存パスを指定
for i in range(10, 16):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                l = "KYI" + str(i) + str(j).zfill(2) + str(k).zfill(2) 
                print(l)

                url = "http://www.jrdb.com/member/datazip/Kyi/20" + str(i) + "/" + l + ".zip"
                savename = "./" + l  + ".zip"

                #ダウンロード --- （＊１）
                nem = urllib.request.urlopen(url).read()

                #ファイルへ保存 --- （＊２）
                with open(savename, mode="wb") as f:
                    f.write(nem)
                    print("保存しました") 
            except:
                pass
            sleep(0.3)
# http://www.jrdb.com/member/datazip/Kyi/2016/KYI160105.zip
# Out:
# KYI180101
# KYI180102
# KYI180103
# KYI180104
# KYI180105
# KYI180106
# 保存しました
# KYI180107
# 保存しました
# KYI180108
# 保存しました
# KYI180109
# KYI180110
# KYI180111
# KYI180112
# KYI180113
# 保存しました
# KYI180114
# 保存しました
# KYI180115
# KYI180116
# KYI180117
# KYI180118
# KYI180119
# KYI180120
# 保存しました
# KYI180121
# 保存しました
# KYI180122
# KYI180123
# KYI180124
# KYI180125
# KYI180126
# KYI180127
# 保存しました
# KYI180128
# 保存しました
# KYI180129
# KYI180130
# KYI180131
# KYI180201
# KYI180202
# KYI180203
# 保存しました
# KYI180204
# 保存しました
# KYI180205
# KYI180206
# KYI180207
# KYI180208
# KYI180209
# KYI180210
# 保存しました
# KYI180211
# 保存しました
# KYI180212
# 保存しました
# KYI180213
# 保存しました
# KYI180214
# KYI180215
# KYI180216
# KYI180217
# 保存しました
# KYI180218
# 保存しました
# KYI180219
# KYI180220
# KYI180221
# KYI180222
# KYI180223
# KYI180224
# 保存しました
# KYI180225
# 保存しました
# KYI180226
# KYI180227
# KYI180228
# KYI180229
# KYI180230
# KYI180231
# KYI180301
# KYI180302
# KYI180303
# 保存しました
# KYI180304
# 保存しました
# KYI180305
# ...

# %%
#URLと保存パスを指定
for i in range(18, 19):
    for j in range(8, 9):
        for k in range(1,32):
            try:
                l = "KYI" + str(i) + str(j).zfill(2) + str(k).zfill(2) 
                print(l)

                url = "http://www.jrdb.com/member/datazip/Kyi/20" + str(i) + "/" + l + ".zip"
                savename = "./" + l  + ".zip"

                #ダウンロード --- （＊１）
                nem = urllib.request.urlopen(url).read()

                #ファイルへ保存 --- （＊２）
                with open(savename, mode="wb") as f:
                    f.write(nem)
                    print("保存しました") 
            except:
                pass
            sleep(0.3)
# http://www.jrdb.com/member/datazip/Kyi/2016/KYI160105.zip
# Out:
# KYI180801
# KYI180802
# KYI180803
# KYI180804
# 保存しました
# KYI180805
# 保存しました
# KYI180806
# KYI180807
# KYI180808
# KYI180809
# KYI180810
# KYI180811
# KYI180812
# KYI180813
# KYI180814
# KYI180815
# KYI180816
# KYI180817
# KYI180818
# KYI180819
# KYI180820
# KYI180821
# KYI180822
# KYI180823
# KYI180824
# KYI180825
# KYI180826
# KYI180827
# KYI180828
# KYI180829
# KYI180830
# KYI180831

# %%
# mybucket = storage.Bucket('keiba_lab/KYI')
# 2016以前も読むようなコード書いておく
df_all = pd.DataFrame()
for i in range(10, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                
                l = "KYI" + str(i) + str(j).zfill(2) + str(k).zfill(2) + ".txt"
                date_test = str(i) + str(j).zfill(2) + str(k).zfill(2)

                filename = './TEST/PACI' + date_test +'/' + l

                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,10),(10,18),(18,36),(36,41),(41,46),(46,51),(51,56),(56,61),(61,66),(66,71),(71,72),(72,73),(73,74),(74,77),(77,82),(82,84),(84,89),(89,91),(91,94),(94,97),(97,100),(100,103),(103,106),(106,109),(109,112),(112,115),(115,118),(118,121),(121,126),(126,131),(131,136),(136,137),(137,138),(138,142),(142,145),(145,147),(147,148),(148,150),(150,152),(152,153),(153,159),(159,162),(162,163),(163,169),(169,171),(171,187),(187,203),(203,219),(219,235),(235,251),(251,259),(259,267),(267,275),(275,283),(283,291),(291,292),(292,294),(294,295),(295,296),(296,297),(297,298),(298,299),(299,300),(300,301),(301,302),(302,303),(303,308),(308,313),(313,314),(314,320),(320,325),(325,326),(326,331),(331,336),(336,341),(341,346),(346,347),(347,349),(349,351),(351,352),(352,354),(354,356),(356,357),(357,359),(359,361),(361,362),(362,363),(363,364),(364,367),(367,370),(370,371),(371,372),(372,392),(392,394),(394,396),(396,398),(398,400),(400,402),(402,404),(404,406),(406,408),(408,412),(412,416),(416,417),(417,425),(425,449),(449,452),(452,455),(455,458),(458,461),(461,464),(464,467),(467,471),(471,475),(475,477),(477,482),(482,485),(485,486),(486,487),(487,489),(489,491),(491,507),(507,509),(509,517),(517,520),(520,545),(545,546),(546,547),(547,945),(945,947)]

                #ファイルを区切った際のカラム名
                names = ['年','回','日','Ｒ','馬番','血統登録番号','馬名','ＩＤＭ','騎手指数','情報指数','予備１','予備２','予備３','総合指数','脚質','距離適性','上昇度','ローテーション','基準オッズ','基準人気順位','基準複勝オッズ','基準複勝人気順位','特定情報◎','特定情報○','特定情報▲','特定情報△','特定情報×','総合情報◎','総合情報○','総合情報▲','総合情報△','総合情報×','人気指数','調教指数','厩舎指数','調教矢印コード','厩舎評価コード','騎手期待連対率','激走指数','蹄コード','重適正コード','クラスコード','予備','ブリンカー','騎手名','負担重量','見習い区分','調教師名','調教師所属','前走１競走成績キー','前走２競走成績キー','前走３競走成績キー','前走４競走成績キー','前走５競走成績キー','前走１レースキー','前走２レースキー','前走３レースキー','前走４レースキー','前走５レースキー','枠番','予備','総合印','ＩＤＭ印','情報印','騎手印','厩舎印','調教印','激走印','芝適性コード','ダ適性コード','騎手コード','調教師コード','予備','獲得賞金','収得賞金','条件クラス','テン指数','ペース指数','上がり指数','位置指数','ペース予想','道中順位','道中差','道中内外','後３Ｆ順位','後３Ｆ差','後３Ｆ内外','ゴール順位','ゴール差','ゴール内外','展開記号','距離適性２','枠確定馬体重','枠確定馬体重増減','取消フラグ','性別コード','馬主名','馬主会コード','馬記号コード','激走順位','LS指数順位','テン指数順位','ペース指数順位','上がり指数順位','位置指数順位','騎手期待単勝率','騎手期待３着内率','輸送区分','走法','体型','体型総合１','体型総合２','体型総合３','馬特記１','馬特記２','馬特記３','馬スタート指数','馬出遅率','参考前走','参考前走騎手コード','万券指数','万券印','降級フラグ','激走タイプ','休養理由分類コード','フラグ','入厩何走目','入厩年月日','入厩何日前','放牧先','放牧先ランク','厩舎ランク','予備','予備']         

                # df = pd.read_fwf(filename,colspecs=colspecs,names=names,converters={'key':np.str},encoding="cp932")
                df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
                df_all = pd.concat([df, df_all], axis = 0)
                print(l)
              
            except:
                pass

# df = pd.read_csv(BytesIO(data))
df_all.shape
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:741: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# KYI180825.txt
# KYI180826.txt
# (521, 134)

# %%
df_kyi = df_all
df_kyi.head()
# Out:
#     年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  情報指数  ...   \
# 1  18  2  4  11   1  13100389  クリーンファンキー　　　　　　　　　  64.1   0.4   0.0  ...
# 1  18  2  4  11   2  13105529  スターオブペルシャ　　　　　　　　　  60.0   0.7  -1.0  ...
# 1  18  2  4  11   3  11104627  ヒルノデイバロー　　　　　　　　　　  70.0   0.4   1.1  ...
# 1  18  2  4  11   4  13104606  ペイシャフェリシタ　　　　　　　　　  62.0   0.3   0.2  ...
# 1  18  2  4  11   5  13106148  ムーンクエイク　　　　　　　　　　　  68.5   1.6   0.7  ...
#
#    休養理由分類コード  フラグ  入厩何走目       入厩年月日  入厩何日前                   放牧先  放牧先ランク  \
# 1        NaN  9.0    3.0  20180711.0    NaN             下河辺牧場日高支場     NaN
# 1        NaN  0.0    6.0  20171219.0    NaN            ミホ分場（ミホ牧場）     NaN
# 1        NaN  0.0    1.0  20180808.0   18.0             ファンタストクラブ     NaN
# 1        NaN  1.0    3.0  20180530.0    NaN              松風馬事センター     NaN
# 1        NaN  0.0    1.0  20180726.0   31.0  ノーザンファーム天栄（旧天栄ホースパーク     NaN
#
#    厩舎ランク  予備.3  予備.4
# 1    NaN     5   NaN
# 1    NaN    A1   NaN
# ...

# %%
df_all["馬名"].value_counts()
# Out:
# ヨシオ　　　　　　　　　　　　　　　    41
# スワンボート　　　　　　　　　　　　    40
# ポロス　　　　　　　　　　　　　　　    37
# デルマサリーチャン　　　　　　　　　    35
# クリノコマチ　　　　　　　　　　　　    34
# ハシカミ　　　　　　　　　　　　　　    34
# キングクリチャン　　　　　　　　　　    33
# エンクエントロス　　　　　　　　　　    33
# ケンホファヴァルト　　　　　　　　　    33
# クリノセゴビア　　　　　　　　　　　    33
# クリノサンスーシ　　　　　　　　　　    33
# ビバラビダ　　　　　　　　　　　　　    32
# ヴァッフシュテルケ　　　　　　　　　    32
# タマモベルガモ　　　　　　　　　　　    32
# エクスシア　　　　　　　　　　　　　    32
# スズカルパン　　　　　　　　　　　　    32
# ビックリシタナモー　　　　　　　　　    32
# ボストンビリーヴ　　　　　　　　　　    32
# アドマイヤツヨシ　　　　　　　　　　    31
# カトルラポール　　　　　　　　　　　    31
# コアレスキング　　　　　　　　　　　    31
# セイウンアワード　　　　　　　　　　    31
# クリノハッチャン　　　　　　　　　　    31
# クリノヴィクトリア　　　　　　　　　    31
# コスモピクシス　　　　　　　　　　　    30
# ビービーブレスユー　　　　　　　　　    30
# ティーエスクライ　　　　　　　　　　    30
# セイカエドミザカ　　　　　　　　　　    30
# モンストルコント　　　　　　　　　　    30
# サンマルホーム　　　　　　　　　　　    30
#                       ..
# ヨウエン　　　　　　　　　　　　　　     1
# セブンチャン　　　　　　　　　　　　     1
# コパハマッテルゼ　　　　　　　　　　     1
# タマモジュニア　　　　　　　　　　　     1
# ヴィクトリアス　　　　　　　　　　　     1
# シェルメール　　　　　　　　　　　　     1
# ...

# %%
df_all.to_csv("df_KYI_all.csv")

# %%
df_kyi = pd.read_csv("df_KYI_all.csv")
df_kyi
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (3,50,55,98,111) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  \
# 0                2  18  2  6  11   1  16100865  ラブミーリッキー　　　　　　　　　　  31.0
# 1                2  18  2  6  11   2  16101053  ガイセン　　　　　　　　　　　　　　  37.0
# 2                2  18  2  6  11   3  16104431  スズカカナロア　　　　　　　　　　　  41.1
# 3                2  18  2  6  11   4  16103849  トーセンオパール　　　　　　　　　　  35.0
# 4                2  18  2  6  11   5  16101865  カルリーノ　　　　　　　　　　　　　  43.0
# 5                2  18  2  6  11   6  16110079  アスターペガサス　　　　　　　　　　  37.0
# 6                2  18  2  6  11   7  16102103  イチゴミルフィーユ　　　　　　　　　  41.0
# 7                2  18  2  6  11   8  16105439  エムティアン　　　　　　　　　　　　  38.1
# ...

# %%
df_kyi = df_kyi.reset_index()
df_kyi = df_kyi.rename(columns={"index":"場コード"})
df_kyi.head()
# Out:
#    場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  ...   \
# 0     1  18  2  4  11   1  13100389  クリーンファンキー　　　　　　　　　  64.1   0.4  ...
# 1     1  18  2  4  11   2  13105529  スターオブペルシャ　　　　　　　　　  60.0   0.7  ...
# 2     1  18  2  4  11   3  11104627  ヒルノデイバロー　　　　　　　　　　  70.0   0.4  ...
# 3     1  18  2  4  11   4  13104606  ペイシャフェリシタ　　　　　　　　　  62.0   0.3  ...
# 4     1  18  2  4  11   5  13106148  ムーンクエイク　　　　　　　　　　　  68.5   1.6  ...
#
#    休養理由分類コード  フラグ  入厩何走目       入厩年月日  入厩何日前                   放牧先  放牧先ランク  \
# 0        NaN  9.0    3.0  20180711.0    NaN             下河辺牧場日高支場     NaN
# 1        NaN  0.0    6.0  20171219.0    NaN            ミホ分場（ミホ牧場）     NaN
# 2        NaN  0.0    1.0  20180808.0   18.0             ファンタストクラブ     NaN
# 3        NaN  1.0    3.0  20180530.0    NaN              松風馬事センター     NaN
# 4        NaN  0.0    1.0  20180726.0   31.0  ノーザンファーム天栄（旧天栄ホースパーク     NaN
#
#    厩舎ランク  予備.3  予備.4
# 0    NaN     5   NaN
# 1    NaN    A1   NaN
# ...

# %%
df_kyi["結果キー"] = df_kyi["場コード"].apply(lambda x: str(x).zfill(2)) + df_kyi["年"].apply(lambda x: str(x).zfill(2)) + df_kyi["回"].astype(str)+ df_kyi["日"].astype(str)+ df_kyi["Ｒ"].apply(lambda x: str(x).zfill(2))+ df_kyi["馬番"].apply(lambda x: str(x).zfill(2))

# %%
# 2016以外も読むコード書いておく
df_SED_all = pd.DataFrame()
for i in range(8, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                l = "SED" + str(i).zfill(2) + str(j).zfill(2) + str(k).zfill(2) + ".txt"
                filename = './SED/' + l
                
                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,10),(10,18),(18,26),(26,44),(44,48),(48,49),(49,50),(50,51),(51,53),(53,55),(55,57),(57,60),(60,61),(61,62),(62,87),(87,89),(89,93),(93,95),(95,96),(96,100),(100,103),(103,109),(109,115),(115,121),(121,123),(123,126),(126,129),(129,132),(132,135),(135,138),(138,141),(141,144),(144,147),(147,150),(150,153),(153,156),(156,157),(157,158),(158,160),(160,161),(161,162),(162,163),(163,164),(164,169),(169,174),(174,179),(179,184),(184,190),(190,193),(193,196),(196,199),(199,223),(223,225),(225,231),(231,237),(237,243),(243,245),(245,247),(247,249),(249,251),(251,254),(254,257),(257,262),(262,267),(267,270),(270,273),(273,274),(274,275),(275,276),(276,283),(283,290),(290,295),(295,300),(300,302),(302,304),(304,305),(305,309)]

                #ファイルを区切った際のカラム名
                names = ["場コード","年","回","日","Ｒ","馬番","血統登録番号","年月日","馬名","距離","芝ダ障害コード","右左","内外","馬場状態","種別","条件","記号","重量","グレード","レース名","頭数","レース名略称","着順","異常区分","タイム","斤量","騎手名","調教師名","確定単勝オッズ","確定単勝人気順位","ＩＤＭ","素点","馬場差","ペース","出遅","位置取","不利","前不利","中不利","後不利","レース","コース取り","上昇度コード","クラスコード","馬体コード","気配コード","レースペース","馬ペース","テン指数","上がり指数","ペース指数","レースＰ指数","1(2)着馬名","1(2)着タイム差","前３Ｆタイム","後３Ｆタイム","備考","予備","確定複勝オッズ下","10時単勝オッズ","10時複勝オッズ","コーナー順位１","コーナー順位２","コーナー順位３","コーナー順位４","前３Ｆ先頭差","後３Ｆ先頭差","騎手コード","調教師コード","馬体重","馬体重増減","天候コード","コース","レース脚質","単勝","複勝","本賞金","収得賞金","レースペース流れ","馬ペース流れ","４角コース取り","予備"]         

                df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
                # df = pd.read_fwf(BytesIO(data),colspecs=colspecs,names=names,encoding="cp932", index_col=0)
                df_SED_all = pd.concat([df, df_SED_all], axis = 0)
                print(l)
              
            except:
                pass

# df = pd.read_csv(BytesIO(data))
df_SED_all.shape
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:741: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# SED080105.txt
# SED080106.txt
# SED080112.txt
# SED080113.txt
# SED080119.txt
# SED080120.txt
# SED080126.txt
# SED080127.txt
# SED080202.txt
# SED080203.txt
# SED080204.txt
# SED080209.txt
# SED080210.txt
# SED080211.txt
# SED080216.txt
# SED080217.txt
# SED080223.txt
# SED080224.txt
# SED080301.txt
# SED080302.txt
# SED080308.txt
# SED080309.txt
# SED080315.txt
# SED080316.txt
# SED080322.txt
# SED080323.txt
# SED080329.txt
# SED080330.txt
# SED080405.txt
# SED080406.txt
# SED080412.txt
# SED080413.txt
# SED080419.txt
# SED080420.txt
# SED080426.txt
# SED080427.txt
# SED080503.txt
# SED080504.txt
# SED080510.txt
# SED080511.txt
# SED080517.txt
# SED080518.txt
# SED080524.txt
# SED080525.txt
# SED080531.txt
# SED080601.txt
# SED080607.txt
# SED080608.txt
# ...

# %%
for i in range(16, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                l = "SED" + str(i) + str(j).zfill(2) + str(k).zfill(2) 
                filename = './SED/' + l + "/" + l + ".txt"
                
                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,10),(10,18),(18,26),(26,44),(44,48),(48,49),(49,50),(50,51),(51,53),(53,55),(55,57),(57,60),(60,61),(61,62),(62,87),(87,89),(89,93),(93,95),(95,96),(96,100),(100,103),(103,109),(109,115),(115,121),(121,123),(123,126),(126,129),(129,132),(132,135),(135,138),(138,141),(141,144),(144,147),(147,150),(150,153),(153,156),(156,157),(157,158),(158,160),(160,161),(161,162),(162,163),(163,164),(164,169),(169,174),(174,179),(179,184),(184,190),(190,193),(193,196),(196,199),(199,223),(223,225),(225,231),(231,237),(237,243),(243,245),(245,247),(247,249),(249,251),(251,254),(254,257),(257,262),(262,267),(267,270),(270,273),(273,274),(274,275),(275,276),(276,283),(283,290),(290,295),(295,300),(300,302),(302,304),(304,305),(305,309)]

                #ファイルを区切った際のカラム名
                names = ["場コード","年","回","日","Ｒ","馬番","血統登録番号","年月日","馬名","距離","芝ダ障害コード","右左","内外","馬場状態","種別","条件","記号","重量","グレード","レース名","頭数","レース名略称","着順","異常区分","タイム","斤量","騎手名","調教師名","確定単勝オッズ","確定単勝人気順位","ＩＤＭ","素点","馬場差","ペース","出遅","位置取","不利","前不利","中不利","後不利","レース","コース取り","上昇度コード","クラスコード","馬体コード","気配コード","レースペース","馬ペース","テン指数","上がり指数","ペース指数","レースＰ指数","1(2)着馬名","1(2)着タイム差","前３Ｆタイム","後３Ｆタイム","備考","予備","確定複勝オッズ下","10時単勝オッズ","10時複勝オッズ","コーナー順位１","コーナー順位２","コーナー順位３","コーナー順位４","前３Ｆ先頭差","後３Ｆ先頭差","騎手コード","調教師コード","馬体重","馬体重増減","天候コード","コース","レース脚質","単勝","複勝","本賞金","収得賞金","レースペース流れ","馬ペース流れ","４角コース取り","予備"]         

                df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
                # df = pd.read_fwf(BytesIO(data),colspecs=colspecs,names=names,encoding="cp932", index_col=0)
                df_SED_all = pd.concat([df, df_SED_all], axis = 0)
                print(l)
              
            except:
                pass

# df = pd.read_csv(BytesIO(data))
df_SED_all.shape
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:741: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# SED170105
# SED170107
# SED170108
# SED170114
# SED170115
# SED170116
# SED170117
# SED170121
# SED170122
# SED170128
# SED170129
# SED170204
# SED170205
# SED170211
# SED170212
# SED170213
# SED170218
# SED170219
# SED170225
# SED170226
# SED170304
# SED170305
# SED170311
# SED170312
# SED170318
# SED170319
# SED170320
# SED170325
# SED170326
# SED170401
# SED170402
# SED170408
# SED170409
# SED170415
# SED170416
# SED170422
# SED170423
# SED170429
# SED170430
# SED170506
# SED170507
# SED170513
# SED170514
# SED170520
# SED170521
# SED170527
# SED170528
# SED170603
# SED170604
# SED170610
# SED170611
# SED170617
# SED170618
# SED170624
# SED170625
# SED170701
# SED170702
# SED170708
# SED170709
# SED170715
# SED170716
# SED170722
# SED170723
# SED170729
# SED170730
# ...

# %%
df_re["騎手名"].value_counts()
# Out:
# 和田竜二　　    950
# 戸崎圭太　　    945
# 内田博幸　　    894
# 柴田大知　　    850
# 幸英明　　　    841
# 大野拓弥　　    835
# 岩田康誠　　    830
# 松山弘平　　    801
# Ｃ．ルメール    769
# 田辺裕信　　    765
# 松若風馬　　    743
# Ｍ．デムーロ    732
# 吉田豊　　　    732
# 蛯名正義　　    727
# 柴山雄一　　    724
# 川田将雅　　    701
# 石川裕紀人　    699
# 福永祐一　　    694
# 藤岡康太　　    672
# 松岡正海　　    671
# 吉田隼人　　    664
# 勝浦正樹　　    664
# 武豊　　　　    651
# 菱田裕二　　    626
# 木幡巧也　　    617
# 鮫島克駿　　    609
# 津村明秀　　    592
# 石橋脩　　　    590
# 柴田善臣　　    580
# 北村友一　　    577
#          ...
# 永森大智　　      8
# 笹川翼　　　      7
# 川原正一　　      7
# 服部茂史　　      7
# 森泰斗　　　      6
# 桑村真明　　      6
# 吉原寛人　　      6
# 丸野勝虎　　      6
# 山本聡哉　　      6
# 町田直希　　      5
# 花田大昂　　      5
# Ｅ．ウィルソ      4
# 宮崎光行　　      4
# 杉浦健太　　      4
# 山口勲　　　      4
# Ｊ．スペンサ      4
# 石川倭　　　      4
# 松井伸也　　      3
# 藤田弘治　　      2
# 左海誠二　　      2
# 阿部龍　　　      2
# Ｂ．プレブル      2
# 今井貴大　　      2
# 早田功駿　　      2
# 鮫島克也　　      2
# 真島大輔　　      2
# 吉村智洋　　      2
# 藤原幹生　　      1
# Ｐ．ブドー　      1
# Ｉ．ファーガ      1
# ...

# %%
df_re = df_re.reset_index(drop=True)

# %%
df_re.to_csv("df_SED_all2.csv")

# %%
df_SED_all = pd.read_csv("df_SED_all.csv", index_col=0)
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,29,31,32,33,34,49,50,51,52,54,55,60,61,66,67,72,73,74,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_SED_all
# Out:
#      場コード   年  回  日   Ｒ  馬番    血統登録番号       年月日                  馬名    距離  \
# 0       2  18  2  4   1   1  16106369  20180715  ラッキーロード　　　　　　　　　　　  1200
# 1       2  18  2  4   1   2  16104201  20180715  カガストロング　　　　　　　　　　　  1200
# 2       2  18  2  4   1   3  16102434  20180715  ロードワンダー　　　　　　　　　　　  1200
# 3       2  18  2  4   1   4  16100943  20180715  シェルトファータ　　　　　　　　　　  1200
# 4       2  18  2  4   1   5  16109057  20180715  ウインベッスル　　　　　　　　　　　  1200
# 5       2  18  2  4   1   6  16102313  20180715  トーセンアトランタ　　　　　　　　　  1200
# 6       2  18  2  4   1   7  16102963  20180715  フレンドリボン　　　　　　　　　　　  1200
# 7       2  18  2  4   1   8  16101717  20180715  ノーリミッツ　　　　　　　　　　　　  1200
# 8       2  18  2  4   1   9  16100558  20180715  モノディアロゴス　　　　　　　　　　  1200
# 9       2  18  2  4   1  10  16105488  20180715  ウインドシャルム　　　　　　　　　　  1200
# 10      2  18  2  4   1  11  16100306  20180715  ヤマチョウヴォイス　　　　　　　　　  1200
# 11      2  18  2  4   1  12  16103442  20180715  ニシノバモス　　　　　　　　　　　　  1200
# ...

# %%
# del df_sed
import gc 
gc.collect()
# Out:
# 143

# %%
del df_SED_all["Unnamed: 0.1"]

# %%
df_sed = df_SED_all

# %%
names = ["結果場コード","結果年","結果回","結果日","結果Ｒ","結果馬番","結果血統登録番号","結果年月日","結果馬名","結果距離","結果芝ダ障害コード","結果右左","結果内外","結果馬場状態","結果種別","結果条件","結果記号","結果重量","結果グレード","結果レース名","結果頭数","結果レース名略称","結果着順","結果異常区分","結果タイム","結果斤量","結果騎手名","結果調教師名","結果確定単勝オッズ","結果確定単勝人気順位","結果ＩＤＭ","結果素点","結果馬場差","結果ペース","結果出遅","結果位置取","結果不利","結果前不利","結果中不利","結果後不利","結果レース","結果コース取り","結果上昇度コード","結果クラスコード","結果馬体コード","結果気配コード","結果レースペース","結果馬ペース","結果テン指数","結果上がり指数","結果ペース指数","結果レースＰ指数","結果1(2)着馬名","結果1(2)着タイム差","結果前３Ｆタイム","結果後３Ｆタイム","結果備考","結果予備","結果確定複勝オッズ下","結果10時単勝オッズ","結果10時複勝オッズ","結果コーナー順位１","結果コーナー順位２","結果コーナー順位３","結果コーナー順位４","結果前３Ｆ先頭差","結果後３Ｆ先頭差","結果騎手コード","結果調教師コード","結果馬体重","結果馬体重増減","結果天候コード","結果コース","結果レース脚質","結果単勝","結果複勝","結果本賞金","結果収得賞金","結果レースペース流れ","結果馬ペース流れ","結果４角コース取り","結果予備"]
df_sed = pd.read_csv("df_SED_all.csv", index_col=0, names=names,skiprows=1)
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,29,31,32,33,34,49,50,51,52,54,55,60,61,66,67,72,73,74,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_sed.shape
# Out:
# (126038, 82)

# %%
df_sed["結果キー"] = df_sed["結果場コード"].apply(lambda x: str(x).zfill(2))  + df_sed["結果年"].apply(lambda x: str(x).zfill(2))+ df_sed["結果回"].astype(str)+ df_sed["結果日"].astype(str)+ df_sed["結果Ｒ"].apply(lambda x: str(x).zfill(2))+ df_sed["結果馬番"].apply(lambda x: str(x).zfill(2))
df_sed.head()
# Out:
#    結果場コード  結果年  結果回 結果日  結果Ｒ  結果馬番  結果血統登録番号     結果年月日                結果馬名  \
# 0       2   18    2   4    1     1  16106369  20180715  ラッキーロード
# 1       2   18    2   4    1     2  16104201  20180715  カガストロング
# 2       2   18    2   4    1     3  16102434  20180715  ロードワンダー
# 3       2   18    2   4    1     4  16100943  20180715  シェルトファータ
# 4       2   18    2   4    1     5  16109057  20180715  ウインベッスル
#
#    結果距離     ...      結果レース脚質  結果単勝  結果複勝  結果本賞金  結果収得賞金 結果レースペース流れ  結果馬ペース流れ  \
# 0  1200     ...            4   NaN   NaN      0       0       22.0      22.0
# 1  1200     ...            4   NaN   NaN      0       0       22.0      11.0
# 2  1200     ...            2   150   110    500     400       22.0      22.0
# 3  1200     ...            1   NaN   NaN      0       0       22.0      33.0
# 4  1200     ...            3   NaN   NaN      0       0       22.0      22.0
#
#    結果４角コース取り  結果予備.1        結果キー
# 0        3.0     NaN  0218240101
# 1        1.0     NaN  0218240102
# ...

# %%
df_all = pd.merge(df_kyi, df_sed, how="left", on="結果キー")

# %%
df_all["結果キー"].value_counts()
# Out:
# 0118230409    1
# 0118231102    1
# 1018290714    1
# 0118231208    1
# 0118230205    1
# 0418290616    1
# 0118231205    1
# 0418291205    1
# 0118230811    1
# 0418290513    1
# 0118231014    1
# 0418291110    1
# 0418291103    1
# 1018290304    1
# 0118230414    1
# 0418290208    1
# 1018290911    1
# 1018291101    1
# 0118230411    1
# 0118230406    1
# 0418290203    1
# 0418290714    1
# 1018290207    1
# 1018290910    1
# 1018290603    1
# 0118231113    1
# 0418290312    1
# 0418290303    1
# 0118230807    1
# 0118230413    1
#              ..
# 1018290810    1
# 04182a1103    1
# 0418290309    1
# 1018290402    1
# 0118230503    1
# 04182a1109    1
# 0418290802    1
# 0418290908    1
# 0118230907    1
# 1018291211    1
# 0418291004    1
# 1018290408    1
# 1018290202    1
# 1018290709    1
# 1018290501    1
# 1018291207    1
# 0418290805    1
# 0118230313    1
# 0418290711    1
# 1018290807    1
# 0418290106    1
# 1018290203    1
# 1018290103    1
# 1018290815    1
# ...

# %%
df_sed[df_sed["結果キー"] == "61618112"]
# Out:
# Empty DataFrame
# Columns: [結果場コード, 結果年, 結果回, 結果日, 結果Ｒ, 結果馬番, 結果血統登録番号, 結果年月日, 結果馬名, 結果距離, 結果芝ダ障害コード, 結果右左, 結果内外, 結果馬場状態, 結果種別, 結果条件, 結果記号, 結果重量, 結果グレード, 結果レース名, 結果頭数, 結果レース名略称, 結果着順, 結果異常区分, 結果タイム, 結果斤量, 結果騎手名, 結果調教師名, 結果確定単勝オッズ, 結果確定単勝人気順位, 結果ＩＤＭ, 結果素点, 結果馬場差, 結果ペース, 結果出遅, 結果位置取, 結果不利, 結果前不利, 結果中不利, 結果後不利, 結果レース, 結果コース取り, 結果上昇度コード, 結果クラスコード, 結果馬体コード, 結果気配コード, 結果レースペース, 結果馬ペース, 結果テン指数, 結果上がり指数, 結果ペース指数, 結果レースＰ指数, 結果1(2)着馬名, 結果1(2)着タイム差, 結果前３Ｆタイム, 結果後３Ｆタイム, 結果備考, 結果予備, 結果確定複勝オッズ下, 結果10時単勝オッズ, 結果10時複勝オッズ, 結果コーナー順位１, 結果コーナー順位２, 結果コーナー順位３, 結果コーナー順位４, 結果前３Ｆ先頭差, 結果後３Ｆ先頭差, 結果騎手コード, 結果調教師コード, 結果馬体重, 結果馬体重増減, 結果天候コード, 結果コース, 結果レース脚質, 結果単勝, 結果複勝, 結果本賞金, 結果収得賞金, 結果レースペース流れ, 結果馬ペース流れ, 結果４角コース取り, 結果予備.1, 結果キー]
# Index: []
#
# [0 rows x 83 columns]

# %%
# names = ["結果場コード","結果年","結果回","結果日","結果Ｒ","結果馬番","結果血統登録番号","結果年月日","結果馬名","結果距離","結果芝ダ障害コード","結果右左","結果内外","結果馬場状態","結果種別","結果条件","結果記号","結果重量","結果グレード","結果レース名","結果頭数","結果レース名略称","結果着順","結果異常区分","結果タイム","結果斤量","結果騎手名","結果調教師名","結果確定単勝オッズ","結果確定単勝人気順位","結果ＩＤＭ","結果素点","結果馬場差","結果ペース","結果出遅","結果位置取","結果不利","結果前不利","結果中不利","結果後不利","結果レース","結果コース取り","結果上昇度コード","結果クラスコード","結果馬体コード","結果気配コード","結果レースペース","結果馬ペース","結果テン指数","結果上がり指数","結果ペース指数","結果レースＰ指数","結果1(2)着馬名","結果1(2)着タイム差","結果前３Ｆタイム","結果後３Ｆタイム","結果備考","結果予備","結果確定複勝オッズ下","結果10時単勝オッズ","結果10時複勝オッズ","結果コーナー順位１","結果コーナー順位２","結果コーナー順位３","結果コーナー順位４","結果前３Ｆ先頭差","結果後３Ｆ先頭差","結果騎手コード","結果調教師コード","結果馬体重","結果馬体重増減","結果天候コード","結果コース","結果レース脚質","結果単勝","結果複勝","結果本賞金","結果収得賞金","結果レースペース流れ","結果馬ペース流れ","結果４角コース取り","結果予備"]
# df_sed = pd.read_csv("df_SED_all.csv", index_col=0, names=names,skiprows=1)
# df_sed["結果キー"] = df_sed["結果場コード"].astype(str) + df_sed["結果年"].astype(str)+ df_sed["結果回"].astype(str)+ df_sed["結果日"].astype(str)+ df_sed["結果Ｒ"].astype(str)+ df_sed["結果馬番"].astype(str)
# df_all = pd.merge(df_kyi, df_sed, how="left", on="結果キー")

# %%
def search_name(name):
    x = re.search("[0-9]", name)
    if x == None:
        return True
    else:
        return False

# %%
import re
# df_SED_all["騎手名"].apply(search_name)
df_re = df_SED_all[df_SED_all["騎手名"].apply(search_name)]

# %%
df_re["年月日"].value_counts()
# Out:
# 20160214    558
# 20160116    556
# 20170218    556
# 20180408    554
# 20160227    553
# 20160501    552
# 20170520    551
# 20171217    550
# 20171216    550
# 20160522    549
# 20170114    548
# 20160220    548
# 20170416    548
# 20170903    548
# 20170409    548
# 20160417    547
# 20160521    546
# 20160410    546
# 20170408    545
# 20180414    545
# 20160221    544
# 20161120    543
# 20160515    543
# 20180519    543
# 20180422    542
# 20160213    541
# 20160416    541
# 20180421    540
# 20161119    540
# 20160430    540
#            ...
# 20170205    339
# 20160911    339
# 20170923    338
# 20180204    337
# 20170924    336
# 20171104    335
# 20170319    335
# 20161127    335
# 20180203    334
# 20161008    334
# 20161009    332
# 20170916    332
# 20171105    330
# 20170402    327
# 20171009    326
# 20171103    318
# 20170918    316
# 20170909    314
# 20170910    311
# 20171008    310
# 20180213    200
# 20170115    190
# 20170116    189
# 20180212    183
# ...

# %%
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(int)
df_all["前走１競走成績キー"].value_counts()
# Out:
# 1.610062e+15    1
# 1.510222e+15    1
# 1.310644e+15    1
# 1.410525e+15    1
# 1.410402e+15    1
# 1.510915e+15    1
# 1.510024e+15    1
# 1.010177e+15    1
# 1.310340e+15    1
# 1.510060e+15    1
# 1.510141e+15    1
# 1.510069e+15    1
# 1.410446e+15    1
# 1.010031e+15    1
# 1.310036e+15    1
# 1.510100e+15    1
# 1.610155e+15    1
# 1.510092e+15    1
# 1.310132e+15    1
# 1.510022e+15    1
# 8.100889e+14    1
# 1.210099e+15    1
# 1.310577e+15    1
# 1.510343e+15    1
# 1.410221e+15    1
# 1.410652e+15    1
# 1.610031e+15    1
# 1.610042e+15    1
# 1.510239e+15    1
# 1.510133e+15    1
#                ..
# 1.510549e+15    1
# 1.510363e+15    1
# 1.510299e+15    1
# 1.510425e+15    1
# 1.510426e+15    1
# 1.210351e+15    1
# 1.210439e+15    1
# 1.510136e+15    1
# 1.510444e+15    1
# 1.510309e+15    1
# 1.310212e+15    1
# 1.510156e+15    1
# 1.410446e+15    1
# 1.610552e+15    1
# 1.510408e+15    1
# 1.510353e+15    1
# 1.510541e+15    1
# 1.410515e+15    1
# 1.410286e+15    1
# ...

# %%
names = ["1走前_場コード","1走前_年","1走前_回","1走前_日","1走前_Ｒ","1走前_馬番","1走前_血統登録番号","1走前_年月日","1走前_馬名","1走前_距離","1走前_芝ダ障害コード","1走前_右左","1走前_内外","1走前_馬場状態","1走前_種別","1走前_条件","1走前_記号","1走前_重量","1走前_グレード","1走前_レース名","1走前_頭数","1走前_レース名略称","1走前_着順","1走前_異常区分","1走前_タイム","1走前_斤量","1走前_騎手名","1走前_調教師名","1走前_確定単勝オッズ","1走前_確定単勝人気順位","1走前_ＩＤＭ","1走前_素点","1走前_馬場差","1走前_ペース","1走前_出遅","1走前_位置取","1走前_不利","1走前_前不利","1走前_中不利","1走前_後不利","1走前_レース","1走前_コース取り","1走前_上昇度コード","1走前_クラスコード","1走前_馬体コード","1走前_気配コード","1走前_レースペース","1走前_馬ペース","1走前_テン指数","1走前_上がり指数","1走前_ペース指数","1走前_レースＰ指数","1走前_1(2)着馬名","1走前_1(2)着タイム差","1走前_前３Ｆタイム","1走前_後３Ｆタイム","1走前_備考","1走前_予備","1走前_確定複勝オッズ下","1走前_10時単勝オッズ","1走前_10時複勝オッズ","1走前_コーナー順位１","1走前_コーナー順位２","1走前_コーナー順位３","1走前_コーナー順位４","1走前_前３Ｆ先頭差","1走前_後３Ｆ先頭差","1走前_騎手コード","1走前_調教師コード","1走前_馬体重","1走前_馬体重増減","1走前_天候コード","1走前_コース","1走前_レース脚質","1走前_単勝","1走前_複勝","1走前_本賞金","1走前_収得賞金","1走前_レースペース流れ","1走前_馬ペース流れ","1走前_４角コース取り","1走前_予備"]
df_sed = pd.read_csv("df_SED_all.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
# 後者だけ桁あわせする
df_sed["前走１競走成績キー"] = (df_sed["1走前_血統登録番号"].astype(str) + df_sed["1走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走１競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,29,31,32,33,34,49,50,51,52,54,55,60,61,66,67,72,73,74,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       1  18  2  4  11   1  13100389  クリーンファンキー　　　　　　　　　  64.1   0.4
# 1       1  18  2  4  11   2  13105529  スターオブペルシャ　　　　　　　　　  60.0   0.7
# 2       1  18  2  4  11   3  11104627  ヒルノデイバロー　　　　　　　　　　  70.0   0.4
# 3       1  18  2  4  11   4  13104606  ペイシャフェリシタ　　　　　　　　　  62.0   0.3
# 4       1  18  2  4  11   5  13106148  ムーンクエイク　　　　　　　　　　　  68.5   1.6
# ...

# %%
予測用データと今回のデータセットを結合してもう一度データセット作って加工、
変換、予測してpredictしないとだめや

# %%
df_all["1走前_馬名"].value_counts()
# Out:
# ヨシオ　　　　　　　　　　　　　　　    40
# スワンボート　　　　　　　　　　　　    39
# ポロス　　　　　　　　　　　　　　　    36
# デルマサリーチャン　　　　　　　　　    34
# クリノコマチ　　　　　　　　　　　　    33
# ケンホファヴァルト　　　　　　　　　    32
# キングクリチャン　　　　　　　　　　    32
# クリノサンスーシ　　　　　　　　　　    32
# クリノセゴビア　　　　　　　　　　　    32
# ハシカミ　　　　　　　　　　　　　　    32
# エンクエントロス　　　　　　　　　　    32
# タマモベルガモ　　　　　　　　　　　    31
# ビバラビダ　　　　　　　　　　　　　    31
# ヴァッフシュテルケ　　　　　　　　　    31
# エクスシア　　　　　　　　　　　　　    31
# スズカルパン　　　　　　　　　　　　    31
# ビックリシタナモー　　　　　　　　　    31
# アドマイヤツヨシ　　　　　　　　　　    30
# セイウンアワード　　　　　　　　　　    30
# クリノハッチャン　　　　　　　　　　    30
# ボストンビリーヴ　　　　　　　　　　    30
# コアレスキング　　　　　　　　　　　    30
# カトルラポール　　　　　　　　　　　    30
# サンマルホーム　　　　　　　　　　　    29
# コスモピクシス　　　　　　　　　　　    29
# セイカエドミザカ　　　　　　　　　　    29
# ティーエスクライ　　　　　　　　　　    29
# ビービーブレスユー　　　　　　　　　    29
# クリノヴィクトリア　　　　　　　　　    29
# キングラディウス　　　　　　　　　　    28
#                       ..
# マイティバローズ　　　　　　　　　　     1
# キスミーオンアイス　　　　　　　　　     1
# シンボリハミルトン　　　　　　　　　     1
# ワイドライジング　　　　　　　　　　     1
# ロワデベット　　　　　　　　　　　　     1
# オールステリーナ　　　　　　　　　　     1
# ...

# %%
# del df_all2
import gc
gc.collect()
# Out:
# 494

# %%
names = ["2走前_場コード","2走前_年","2走前_回","2走前_日","2走前_Ｒ","2走前_馬番","2走前_血統登録番号","2走前_年月日","2走前_馬名","2走前_距離","2走前_芝ダ障害コード","2走前_右左","2走前_内外","2走前_馬場状態","2走前_種別","2走前_条件","2走前_記号","2走前_重量","2走前_グレード","2走前_レース名","2走前_頭数","2走前_レース名略称","2走前_着順","2走前_異常区分","2走前_タイム","2走前_斤量","2走前_騎手名","2走前_調教師名","2走前_確定単勝オッズ","2走前_確定単勝人気順位","2走前_ＩＤＭ","2走前_素点","2走前_馬場差","2走前_ペース","2走前_出遅","2走前_位置取","2走前_不利","2走前_前不利","2走前_中不利","2走前_後不利","2走前_レース","2走前_コース取り","2走前_上昇度コード","2走前_クラスコード","2走前_馬体コード","2走前_気配コード","2走前_レースペース","2走前_馬ペース","2走前_テン指数","2走前_上がり指数","2走前_ペース指数","2走前_レースＰ指数","2走前_1(2)着馬名","2走前_1(2)着タイム差","2走前_前３Ｆタイム","2走前_後３Ｆタイム","2走前_備考","2走前_予備","2走前_確定複勝オッズ下","2走前_10時単勝オッズ","2走前_10時複勝オッズ","2走前_コーナー順位１","2走前_コーナー順位２","2走前_コーナー順位３","2走前_コーナー順位４","2走前_前３Ｆ先頭差","2走前_後３Ｆ先頭差","2走前_騎手コード","2走前_調教師コード","2走前_馬体重","2走前_馬体重増減","2走前_天候コード","2走前_コース","2走前_レース脚質","2走前_単勝","2走前_複勝","2走前_本賞金","2走前_収得賞金","2走前_レースペース流れ","2走前_馬ペース流れ","2走前_４角コース取り","2走前_予備"]
df_sed = pd.read_csv("df_SED_all.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
df_sed["前走２競走成績キー"] = (df_sed["2走前_血統登録番号"].astype(str) + df_sed["2走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走２競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,29,31,32,33,34,49,50,51,52,54,55,60,61,66,67,72,73,74,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       1  18  2  4  11   1  13100389  クリーンファンキー　　　　　　　　　  64.1   0.4
# 1       1  18  2  4  11   2  13105529  スターオブペルシャ　　　　　　　　　  60.0   0.7
# 2       1  18  2  4  11   3  11104627  ヒルノデイバロー　　　　　　　　　　  70.0   0.4
# 3       1  18  2  4  11   4  13104606  ペイシャフェリシタ　　　　　　　　　  62.0   0.3
# 4       1  18  2  4  11   5  13106148  ムーンクエイク　　　　　　　　　　　  68.5   1.6
# ...

# %%
names = ["3走前_場コード","3走前_年","3走前_回","3走前_日","3走前_Ｒ","3走前_馬番","3走前_血統登録番号","3走前_年月日","3走前_馬名","3走前_距離","3走前_芝ダ障害コード","3走前_右左","3走前_内外","3走前_馬場状態","3走前_種別","3走前_条件","3走前_記号","3走前_重量","3走前_グレード","3走前_レース名","3走前_頭数","3走前_レース名略称","3走前_着順","3走前_異常区分","3走前_タイム","3走前_斤量","3走前_騎手名","3走前_調教師名","3走前_確定単勝オッズ","3走前_確定単勝人気順位","3走前_ＩＤＭ","3走前_素点","3走前_馬場差","3走前_ペース","3走前_出遅","3走前_位置取","3走前_不利","3走前_前不利","3走前_中不利","3走前_後不利","3走前_レース","3走前_コース取り","3走前_上昇度コード","3走前_クラスコード","3走前_馬体コード","3走前_気配コード","3走前_レースペース","3走前_馬ペース","3走前_テン指数","3走前_上がり指数","3走前_ペース指数","3走前_レースＰ指数","3走前_1(2)着馬名","3走前_1(2)着タイム差","3走前_前３Ｆタイム","3走前_後３Ｆタイム","3走前_備考","3走前_予備","3走前_確定複勝オッズ下","3走前_10時単勝オッズ","3走前_10時複勝オッズ","3走前_コーナー順位１","3走前_コーナー順位２","3走前_コーナー順位３","3走前_コーナー順位４","3走前_前３Ｆ先頭差","3走前_後３Ｆ先頭差","3走前_騎手コード","3走前_調教師コード","3走前_馬体重","3走前_馬体重増減","3走前_天候コード","3走前_コース","3走前_レース脚質","3走前_単勝","3走前_複勝","3走前_本賞金","3走前_収得賞金","3走前_レースペース流れ","3走前_馬ペース流れ","3走前_４角コース取り","3走前_予備"]
df_sed = pd.read_csv("df_SED_all.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
df_sed["前走３競走成績キー"] = (df_sed["3走前_血統登録番号"].astype(str) + df_sed["3走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走３競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,29,31,32,33,34,49,50,51,52,54,55,60,61,66,67,72,73,74,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       1  18  2  4  11   1  13100389  クリーンファンキー　　　　　　　　　  64.1   0.4
# 1       1  18  2  4  11   2  13105529  スターオブペルシャ　　　　　　　　　  60.0   0.7
# 2       1  18  2  4  11   3  11104627  ヒルノデイバロー　　　　　　　　　　  70.0   0.4
# 3       1  18  2  4  11   4  13104606  ペイシャフェリシタ　　　　　　　　　  62.0   0.3
# 4       1  18  2  4  11   5  13106148  ムーンクエイク　　　　　　　　　　　  68.5   1.6
# ...

# %%
names = ["4走前_場コード","4走前_年","4走前_回","4走前_日","4走前_Ｒ","4走前_馬番","4走前_血統登録番号","4走前_年月日","4走前_馬名","4走前_距離","4走前_芝ダ障害コード","4走前_右左","4走前_内外","4走前_馬場状態","4走前_種別","4走前_条件","4走前_記号","4走前_重量","4走前_グレード","4走前_レース名","4走前_頭数","4走前_レース名略称","4走前_着順","4走前_異常区分","4走前_タイム","4走前_斤量","4走前_騎手名","4走前_調教師名","4走前_確定単勝オッズ","4走前_確定単勝人気順位","4走前_ＩＤＭ","4走前_素点","4走前_馬場差","4走前_ペース","4走前_出遅","4走前_位置取","4走前_不利","4走前_前不利","4走前_中不利","4走前_後不利","4走前_レース","4走前_コース取り","4走前_上昇度コード","4走前_クラスコード","4走前_馬体コード","4走前_気配コード","4走前_レースペース","4走前_馬ペース","4走前_テン指数","4走前_上がり指数","4走前_ペース指数","4走前_レースＰ指数","4走前_1(2)着馬名","4走前_1(2)着タイム差","4走前_前３Ｆタイム","4走前_後３Ｆタイム","4走前_備考","4走前_予備","4走前_確定複勝オッズ下","4走前_10時単勝オッズ","4走前_10時複勝オッズ","4走前_コーナー順位１","4走前_コーナー順位２","4走前_コーナー順位３","4走前_コーナー順位４","4走前_前３Ｆ先頭差","4走前_後３Ｆ先頭差","4走前_騎手コード","4走前_調教師コード","4走前_馬体重","4走前_馬体重増減","4走前_天候コード","4走前_コース","4走前_レース脚質","4走前_単勝","4走前_複勝","4走前_本賞金","4走前_収得賞金","4走前_レースペース流れ","4走前_馬ペース流れ","4走前_４角コース取り","4走前_予備"]
df_sed = pd.read_csv("df_SED_all.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
df_sed["前走４競走成績キー"] = (df_sed["4走前_血統登録番号"].astype(str) + df_sed["4走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走４競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,29,31,32,33,34,49,50,51,52,54,55,60,61,66,67,72,73,74,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       1  18  2  4  11   1  13100389  クリーンファンキー　　　　　　　　　  64.1   0.4
# 1       1  18  2  4  11   2  13105529  スターオブペルシャ　　　　　　　　　  60.0   0.7
# 2       1  18  2  4  11   3  11104627  ヒルノデイバロー　　　　　　　　　　  70.0   0.4
# 3       1  18  2  4  11   4  13104606  ペイシャフェリシタ　　　　　　　　　  62.0   0.3
# 4       1  18  2  4  11   5  13106148  ムーンクエイク　　　　　　　　　　　  68.5   1.6
# ...

# %%
names = ["5走前_場コード","5走前_年","5走前_回","5走前_日","5走前_Ｒ","5走前_馬番","5走前_血統登録番号","5走前_年月日","5走前_馬名","5走前_距離","5走前_芝ダ障害コード","5走前_右左","5走前_内外","5走前_馬場状態","5走前_種別","5走前_条件","5走前_記号","5走前_重量","5走前_グレード","5走前_レース名","5走前_頭数","5走前_レース名略称","5走前_着順","5走前_異常区分","5走前_タイム","5走前_斤量","5走前_騎手名","5走前_調教師名","5走前_確定単勝オッズ","5走前_確定単勝人気順位","5走前_ＩＤＭ","5走前_素点","5走前_馬場差","5走前_ペース","5走前_出遅","5走前_位置取","5走前_不利","5走前_前不利","5走前_中不利","5走前_後不利","5走前_レース","5走前_コース取り","5走前_上昇度コード","5走前_クラスコード","5走前_馬体コード","5走前_気配コード","5走前_レースペース","5走前_馬ペース","5走前_テン指数","5走前_上がり指数","5走前_ペース指数","5走前_レースＰ指数","5走前_1(2)着馬名","5走前_1(2)着タイム差","5走前_前３Ｆタイム","5走前_後３Ｆタイム","5走前_備考","5走前_予備","5走前_確定複勝オッズ下","5走前_10時単勝オッズ","5走前_10時複勝オッズ","5走前_コーナー順位１","5走前_コーナー順位２","5走前_コーナー順位３","5走前_コーナー順位４","5走前_前３Ｆ先頭差","5走前_後３Ｆ先頭差","5走前_騎手コード","5走前_調教師コード","5走前_馬体重","5走前_馬体重増減","5走前_天候コード","5走前_コース","5走前_レース脚質","5走前_単勝","5走前_複勝","5走前_本賞金","5走前_収得賞金","5走前_レースペース流れ","5走前_馬ペース流れ","5走前_４角コース取り","5走前_予備"]
df_sed = pd.read_csv("df_SED_all.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
df_sed["前走５競走成績キー"] = (df_sed["5走前_血統登録番号"].astype(str) + df_sed["5走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走５競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,29,31,32,33,34,49,50,51,52,54,55,60,61,66,67,72,73,74,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       1  18  2  4  11   1  13100389  クリーンファンキー　　　　　　　　　  64.1   0.4
# 1       1  18  2  4  11   2  13105529  スターオブペルシャ　　　　　　　　　  60.0   0.7
# 2       1  18  2  4  11   3  11104627  ヒルノデイバロー　　　　　　　　　　  70.0   0.4
# 3       1  18  2  4  11   4  13104606  ペイシャフェリシタ　　　　　　　　　  62.0   0.3
# 4       1  18  2  4  11   5  13106148  ムーンクエイク　　　　　　　　　　　  68.5   1.6
# ...

# %%
df_all["1走前_馬名"].value_counts()
# Out:
# ヨシオ　　　　　　　　　　　　　　　    40
# スワンボート　　　　　　　　　　　　    39
# ポロス　　　　　　　　　　　　　　　    36
# デルマサリーチャン　　　　　　　　　    34
# クリノコマチ　　　　　　　　　　　　    33
# ケンホファヴァルト　　　　　　　　　    32
# キングクリチャン　　　　　　　　　　    32
# クリノサンスーシ　　　　　　　　　　    32
# クリノセゴビア　　　　　　　　　　　    32
# ハシカミ　　　　　　　　　　　　　　    32
# エンクエントロス　　　　　　　　　　    32
# タマモベルガモ　　　　　　　　　　　    31
# ビバラビダ　　　　　　　　　　　　　    31
# ヴァッフシュテルケ　　　　　　　　　    31
# エクスシア　　　　　　　　　　　　　    31
# スズカルパン　　　　　　　　　　　　    31
# ビックリシタナモー　　　　　　　　　    31
# アドマイヤツヨシ　　　　　　　　　　    30
# セイウンアワード　　　　　　　　　　    30
# クリノハッチャン　　　　　　　　　　    30
# ボストンビリーヴ　　　　　　　　　　    30
# コアレスキング　　　　　　　　　　　    30
# カトルラポール　　　　　　　　　　　    30
# サンマルホーム　　　　　　　　　　　    29
# コスモピクシス　　　　　　　　　　　    29
# セイカエドミザカ　　　　　　　　　　    29
# ティーエスクライ　　　　　　　　　　    29
# ビービーブレスユー　　　　　　　　　    29
# クリノヴィクトリア　　　　　　　　　    29
# キングラディウス　　　　　　　　　　    28
#                       ..
# マイティバローズ　　　　　　　　　　     1
# キスミーオンアイス　　　　　　　　　     1
# シンボリハミルトン　　　　　　　　　     1
# ワイドライジング　　　　　　　　　　     1
# ロワデベット　　　　　　　　　　　　     1
# オールステリーナ　　　　　　　　　　     1
# ...

# %%
df_all.to_csv("df_all_180803.csv")

# %%
df_all_head = pd.read_csv("df_all_180722_head100.csv")

# %%
df_all["1走前_馬体重"].value_counts()

# %%
df_all.head()

# %%
df_all["結果タイム"].value_counts()
# Out:
# 0.0       361
# 1124.0    184
# 1123.0    179
# 1099.0    176
# 1121.0    171
# 1101.0    171
# 1119.0    171
# 1122.0    169
# 1127.0    168
# 1126.0    166
# 1130.0    166
# 1095.0    163
# 1116.0    162
# 1104.0    161
# 1125.0    160
# 1118.0    159
# 1096.0    159
# 1128.0    159
# 1131.0    158
# 1103.0    156
# 1098.0    155
# 1132.0    153
# 1138.0    153
# 1134.0    153
# 1108.0    152
# 1105.0    151
# 1117.0    151
# 1094.0    150
# 1487.0    150
# 1097.0    149
#          ...
# 2493.0      1
# 2525.0      1
# 3321.0      1
# 3320.0      1
# 3508.0      1
# 3493.0      1
# 3398.0      1
# 4509.0      1
# 4511.0      1
# 3181.0      1
# 4538.0      1
# 3491.0      1
# 4517.0      1
# 4259.0      1
# 4314.0      1
# 2225.0      1
# 3496.0      1
# 3455.0      1
# 3479.0      1
# 3506.0      1
# 4531.0      1
# 4249.0      1
# 4247.0      1
# 4537.0      1
# 3328.0      1
# 2465.0      1
# 4544.0      1
# 3507.0      1
# 2463.0      1
# 4471.0      1
# ...

# %%
df_kyi.columns.values
# Out:
# array(['場コード', '年', '回', '日', 'Ｒ', '馬番', '血統登録番号', '馬名', 'ＩＤＭ', '騎手指数',
#        '情報指数', '予備１', '予備２', '予備３', '総合指数', '脚質', '距離適性', '上昇度',
#        'ローテーション', '基準オッズ', '基準人気順位', '基準複勝オッズ', '基準複勝人気順位', '特定情報◎',
#        '特定情報○', '特定情報▲', '特定情報△', '特定情報×', '総合情報◎', '総合情報○', '総合情報▲',
#        '総合情報△', '総合情報×', '人気指数', '調教指数', '厩舎指数', '調教矢印コード', '厩舎評価コード',
#        '騎手期待連対率', '激走指数', '蹄コード', '重適正コード', 'クラスコード', '予備', 'ブリンカー',
#        '騎手名', '負担重量', '見習い区分', '調教師名', '調教師所属', '前走１競走成績キー', '前走２競走成績キー',
#        '前走３競走成績キー', '前走４競走成績キー', '前走５競走成績キー', '前走１レースキー', '前走２レースキー',
#        '前走３レースキー', '前走４レースキー', '前走５レースキー', '枠番', '予備.1', '総合印', 'ＩＤＭ印',
#        '情報印', '騎手印', '厩舎印', '調教印', '激走印', '芝適性コード', 'ダ適性コード', '騎手コード',
#        '調教師コード', '予備.2', '獲得賞金', '収得賞金', '条件クラス', 'テン指数', 'ペース指数',
#        '上がり指数', '位置指数', 'ペース予想', '道中順位', '道中差', '道中内外', '後３Ｆ順位', '後３Ｆ差',
#        '後３Ｆ内外', 'ゴール順位', 'ゴール差', 'ゴール内外', '展開記号', '距離適性２', '枠確定馬体重',
# ...

# %%
df_all2["1走前_馬名"].value_counts()
# Out:
# ヨシオ　　　　　　　　　　　　　　　    41
# クリノコマチ　　　　　　　　　　　　    39
# スワンボート　　　　　　　　　　　　    39
# ポロス　　　　　　　　　　　　　　　    37
# スズカルパン　　　　　　　　　　　　    37
# クリノハッチャン　　　　　　　　　　    36
# クリノセゴビア　　　　　　　　　　　    35
# ゲッカコウ　　　　　　　　　　　　　    35
# デルマサリーチャン　　　　　　　　　    35
# クリノサンスーシ　　　　　　　　　　    35
# ケンホファヴァルト　　　　　　　　　    34
# ヴァッフシュテルケ　　　　　　　　　    33
# キングクリチャン　　　　　　　　　　    33
# コウエイタケル　　　　　　　　　　　    33
# ハシカミ　　　　　　　　　　　　　　    32
# サンマルホーム　　　　　　　　　　　    32
# コアレスキング　　　　　　　　　　　    32
# エンクエントロス　　　　　　　　　　    32
# ラインスピリット　　　　　　　　　　    32
# コスモドーム　　　　　　　　　　　　    31
# ビバラビダ　　　　　　　　　　　　　    31
# ビックリシタナモー　　　　　　　　　    31
# タマモベルガモ　　　　　　　　　　　    31
# エクスシア　　　　　　　　　　　　　    31
# ビービーブレスユー　　　　　　　　　    30
# セイカエドミザカ　　　　　　　　　　    30
# アドマイヤツヨシ　　　　　　　　　　    30
# セイウンアワード　　　　　　　　　　    30
# リーゼントロック　　　　　　　　　　    30
# カトルラポール　　　　　　　　　　　    30
#                       ..
# リベラメンテ　　　　　　　　　　　　     1
# ノブジョプリン　　　　　　　　　　　     1
# ジョリフィーユ　　　　　　　　　　　     1
# オモロイシャチョウ　　　　　　　　　     1
# ヤマカツクリスエス　　　　　　　　　     1
# ワンラヴワンハート　　　　　　　　　     1
# ...

# %%
df_kyi.head()
# Out:
#    場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数    ...     \
# 0     2  18  2  6  11   1  16100865  ラブミーリッキー　　　　　　　　　　  31.0   0.4    ...
# 1     2  18  2  6  11   2  16101053  ガイセン　　　　　　　　　　　　　　  37.0   0.3    ...
# 2     2  18  2  6  11   3  16104431  スズカカナロア　　　　　　　　　　　  41.1   1.1    ...
# 3     2  18  2  6  11   4  16103849  トーセンオパール　　　　　　　　　　  35.0   1.3    ...
# 4     2  18  2  6  11   5  16101865  カルリーノ　　　　　　　　　　　　　  43.0   1.4    ...
#
#         フラグ  入厩何走目       入厩年月日  入厩何日前            放牧先  放牧先ランク  厩舎ランク  予備.3  \
# 0  213000.0    2.0  20180512.0    NaN      クイーンズ・ランチ     NaN    NaN     5
# 1    3001.0    2.0  20180516.0    NaN         シンボリ牧場     NaN    NaN    C8
# 2    3001.0    2.0  20180509.0    NaN   ノーザンファームしがらき     NaN    NaN    A2
# 3    3000.0    2.0  20180602.0    NaN    エスティファーム小見川     NaN    NaN    C5
# 4    3001.0    3.0  20180428.0    NaN  ディアレストクラブイースト     NaN    NaN    B7
#
#    予備.4      結果キー
# 0   NaN  21826111
# 1   NaN  21826112
# ...

# %%
df_kyi.columns.values
# Out:
# array(['場コード', '年', '回', '日', 'Ｒ', '馬番', '血統登録番号', '馬名', 'ＩＤＭ', '騎手指数',
#        '情報指数', '予備１', '予備２', '予備３', '総合指数', '脚質', '距離適性', '上昇度',
#        'ローテーション', '基準オッズ', '基準人気順位', '基準複勝オッズ', '基準複勝人気順位', '特定情報◎',
#        '特定情報○', '特定情報▲', '特定情報△', '特定情報×', '総合情報◎', '総合情報○', '総合情報▲',
#        '総合情報△', '総合情報×', '人気指数', '調教指数', '厩舎指数', '調教矢印コード', '厩舎評価コード',
#        '騎手期待連対率', '激走指数', '蹄コード', '重適正コード', 'クラスコード', '予備', 'ブリンカー',
#        '騎手名', '負担重量', '見習い区分', '調教師名', '調教師所属', '前走１競走成績キー', '前走２競走成績キー',
#        '前走３競走成績キー', '前走４競走成績キー', '前走５競走成績キー', '前走１レースキー', '前走２レースキー',
#        '前走３レースキー', '前走４レースキー', '前走５レースキー', '枠番', '予備.1', '総合印', 'ＩＤＭ印',
#        '情報印', '騎手印', '厩舎印', '調教印', '激走印', '芝適性コード', 'ダ適性コード', '騎手コード',
#        '調教師コード', '予備.2', '獲得賞金', '収得賞金', '条件クラス', 'テン指数', 'ペース指数',
#        '上がり指数', '位置指数', 'ペース予想', '道中順位', '道中差', '道中内外', '後３Ｆ順位', '後３Ｆ差',
#        '後３Ｆ内外', 'ゴール順位', 'ゴール差', 'ゴール内外', '展開記号', '距離適性２', '枠確定馬体重',
# ...

# %%
df_kyi["結果キー"] = df_kyi["場コード"].astype(str) + df_kyi["年"].astype(str)+ df_kyi["回"].astype(str)+ df_kyi["日"].astype(str)+ df_kyi["Ｒ"].astype(str)+ df_kyi["馬番"].astype(str)
# df_kyi = df_kyi.rename(columns={"Unnamed: 0":"場コード"})
df_kyi.head()
# Out:
#    場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数    ...     \
# 0     1  18  2  4  11   1  13100389  クリーンファンキー　　　　　　　　　  64.1   0.4    ...
# 1     1  18  2  4  11   2  13105529  スターオブペルシャ　　　　　　　　　  60.0   0.7    ...
# 2     1  18  2  4  11   3  11104627  ヒルノデイバロー　　　　　　　　　　  70.0   0.4    ...
# 3     1  18  2  4  11   4  13104606  ペイシャフェリシタ　　　　　　　　　  62.0   0.3    ...
# 4     1  18  2  4  11   5  13106148  ムーンクエイク　　　　　　　　　　　  68.5   1.6    ...
#
#    フラグ  入厩何走目       入厩年月日  入厩何日前                   放牧先  放牧先ランク  厩舎ランク  予備.3  \
# 0  9.0    3.0  20180711.0    NaN             下河辺牧場日高支場     NaN    NaN     5
# 1  0.0    6.0  20171219.0    NaN            ミホ分場（ミホ牧場）     NaN    NaN    A1
# 2  0.0    1.0  20180808.0   18.0             ファンタストクラブ     NaN    NaN    B2
# 3  1.0    3.0  20180530.0    NaN              松風馬事センター     NaN    NaN    C3
# 4  0.0    1.0  20180726.0   31.0  ノーザンファーム天栄（旧天栄ホースパーク     NaN    NaN    A1
#
#    予備.4      結果キー
# 0   NaN  11824111
# ...

# %%
# df_kyi.columns.values
df_kyi["前走１競走成績キー"].value_counts()
# Out:
# 1.410202e+15    1
# 1.310632e+15    1
# 1.210059e+15    1
# 1.210490e+15    1
# 1.410115e+15    1
# 1.310157e+15    1
# 1.410513e+15    1
# 1.310090e+15    1
# 1.310404e+15    1
# 1.310173e+15    1
# 1.310218e+15    1
# 1.210534e+15    1
# 1.410192e+15    1
# 1.510036e+15    1
# 1.410052e+15    1
# 1.410081e+15    1
# 1.510588e+15    1
# 1.310234e+15    1
# 1.510180e+15    1
# 1.510555e+15    1
# 1.210254e+15    1
# 1.510046e+15    1
# 1.510444e+15    1
# 1.510225e+15    1
# 1.310627e+15    1
# 1.210579e+15    1
# 1.310055e+15    1
# 1.219000e+15    1
# 1.210207e+15    1
# 1.610416e+15    1
#                ..
# 1.010225e+15    1
# 1.110399e+15    1
# 1.310308e+15    1
# 1.110497e+15    1
# 1.010121e+15    1
# 1.210638e+15    1
# 1.510015e+15    1
# 1.210539e+15    1
# 1.110415e+15    1
# 1.110486e+15    1
# 1.410101e+15    1
# 1.510175e+15    1
# 1.410612e+15    1
# 1.410025e+15    1
# 1.310283e+15    1
# 1.410038e+15    1
# 1.210087e+15    1
# 1.110442e+15    1
# 1.010133e+15    1
# ...

# %%
# df_sed["競走成績キー"] = df_sed["血統登録番号"].astype(str) + df_sed["年月日"].astype(str)
df_sed.head()
# Out:
#    5走前_場コード  5走前_年  5走前_回 5走前_日  5走前_Ｒ  5走前_馬番  5走前_血統登録番号   5走前_年月日  \
# 0         2     18      2     4      1       1    16106369  20180715
# 1         2     18      2     4      1       2    16104201  20180715
# 2         2     18      2     4      1       3    16102434  20180715
# 3         2     18      2     4      1       4    16100943  20180715
# 4         2     18      2     4      1       5    16109057  20180715
#
#                5走前_馬名  5走前_距離        ...         5走前_レース脚質  5走前_単勝  5走前_複勝  \
# 0  ラッキーロード　　　　　　　　　　　    1200        ...                 4     NaN     NaN
# 1  カガストロング　　　　　　　　　　　    1200        ...                 4     NaN     NaN
# 2  ロードワンダー　　　　　　　　　　　    1200        ...                 2     150     110
# 3  シェルトファータ　　　　　　　　　　    1200        ...                 1     NaN     NaN
# 4  ウインベッスル　　　　　　　　　　　    1200        ...                 3     NaN     NaN
#
#    5走前_本賞金  5走前_収得賞金 5走前_レースペース流れ  5走前_馬ペース流れ  5走前_４角コース取り  5走前_予備.1  \
# ...

# %%
df_all = pd.DataFrame()
for i in range(16, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                
                l = "SED" + str(i) + str(j).zfill(2) + str(k).zfill(2) + ".txt"

                filename = './SED/' + l

                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,10),(10,18),(18,26),(26,44),(44,48),(48,49),(49,50),(50,51),(51,53),(53,55),(55,57),(57,60),(60,61),(61,62),(62,87),(87,89),(89,93),(93,95),(95,96),(96,100),(100,103),(103,109),(109,115),(115,121),(121,123),(123,126),(126,129),(129,132),(132,135),(135,138),(138,141),(141,144),(144,147),(147,150),(150,153),(153,156),(156,157),(157,158),(158,160),(160,161),(161,162),(162,163),(163,164),(164,169),(169,174),(174,179),(179,184),(184,190),(190,193),(193,196),(196,199),(199,223),(223,225),(225,231),(231,237),(237,243),(243,245),(245,247),(247,249),(249,251),(251,254),(254,257),(257,262),(262,267),(267,270),(270,273),(273,274),(274,275),(275,276),(276,283),(283,290),(290,295),(295,300),(300,302),(302,304),(304,305),(305,309)]

              #ファイルを区切った際のカラム名
                names = ["場コード","年","回","日","Ｒ","馬番","血統登録番号","年月日","馬名","距離","芝ダ障害コード","右左","内外","馬場状態","種別","条件","記号","重量","グレード","レース名","頭数","レース名略称","着順","異常区分","タイム","斤量","騎手名","調教師名","確定単勝オッズ","確定単勝人気順位","ＩＤＭ","素点","馬場差","ペース","出遅","位置取","不利","前不利","中不利","後不利","レース","コース取り","上昇度コード","クラスコード","馬体コード","気配コード","レースペース","馬ペース","テン指数","上がり指数","ペース指数","レースＰ指数","1(2)着馬名","1(2)着タイム差","前３Ｆタイム","後３Ｆタイム","備考","予備","確定複勝オッズ下","10時単勝オッズ","10時複勝オッズ","コーナー順位１","コーナー順位２","コーナー順位３","コーナー順位４","前３Ｆ先頭差","後３Ｆ先頭差","騎手コード","調教師コード","馬体重","馬体重増減","天候コード","コース","レース脚質","単勝","複勝","本賞金","収得賞金","レースペース流れ","馬ペース流れ","４角コース取り","予備"]         

                # df = pd.read_fwf(filename,colspecs=colspecs,names=names,converters={'key':np.str},encoding="cp932")
                df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
                df_all = pd.concat([df, df_all], axis = 0)
                print(l)
              
            except:
                pass

# df = pd.read_csv(BytesIO(data))
df_all.shape
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:741: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# SED160105.txt
# SED160109.txt
# SED160110.txt
# SED160111.txt
# SED160116.txt
# SED160117.txt
# SED160123.txt
# SED160124.txt
# SED160130.txt
# SED160131.txt
# SED160206.txt
# SED160207.txt
# SED160213.txt
# SED160214.txt
# SED160220.txt
# SED160221.txt
# SED160227.txt
# SED160228.txt
# SED160305.txt
# SED160306.txt
# SED160312.txt
# SED160313.txt
# SED160319.txt
# SED160320.txt
# SED160321.txt
# SED160326.txt
# SED160327.txt
# SED160402.txt
# SED160403.txt
# SED160409.txt
# SED160410.txt
# SED160416.txt
# SED160417.txt
# SED160423.txt
# SED160424.txt
# SED160430.txt
# SED160501.txt
# SED160507.txt
# SED160508.txt
# SED160514.txt
# SED160515.txt
# SED160521.txt
# SED160522.txt
# SED160528.txt
# SED160529.txt
# SED160604.txt
# SED160605.txt
# SED160611.txt
# ...

# %%
for i in range(16, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                
                l = "SED" + str(i) + str(j).zfill(2) + str(k).zfill(2) 

                filename = './SED/' + l + "/" + l + ".txt"

                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,10),(10,18),(18,26),(26,44),(44,48),(48,49),(49,50),(50,51),(51,53),(53,55),(55,57),(57,60),(60,61),(61,62),(62,87),(87,89),(89,93),(93,95),(95,96),(96,100),(100,103),(103,109),(109,115),(115,121),(121,123),(123,126),(126,129),(129,132),(132,135),(135,138),(138,141),(141,144),(144,147),(147,150),(150,153),(153,156),(156,157),(157,158),(158,160),(160,161),(161,162),(162,163),(163,164),(164,169),(169,174),(174,179),(179,184),(184,190),(190,193),(193,196),(196,199),(199,223),(223,225),(225,231),(231,237),(237,243),(243,245),(245,247),(247,249),(249,251),(251,254),(254,257),(257,262),(262,267),(267,270),(270,273),(273,274),(274,275),(275,276),(276,283),(283,290),(290,295),(295,300),(300,302),(302,304),(304,305),(305,309)]

              #ファイルを区切った際のカラム名
                names = ["場コード","年","回","日","Ｒ","馬番","血統登録番号","年月日","馬名","距離","芝ダ障害コード","右左","内外","馬場状態","種別","条件","記号","重量","グレード","レース名","頭数","レース名略称","着順","異常区分","タイム","斤量","騎手名","調教師名","確定単勝オッズ","確定単勝人気順位","ＩＤＭ","素点","馬場差","ペース","出遅","位置取","不利","前不利","中不利","後不利","レース","コース取り","上昇度コード","クラスコード","馬体コード","気配コード","レースペース","馬ペース","テン指数","上がり指数","ペース指数","レースＰ指数","1(2)着馬名","1(2)着タイム差","前３Ｆタイム","後３Ｆタイム","備考","予備","確定複勝オッズ下","10時単勝オッズ","10時複勝オッズ","コーナー順位１","コーナー順位２","コーナー順位３","コーナー順位４","前３Ｆ先頭差","後３Ｆ先頭差","騎手コード","調教師コード","馬体重","馬体重増減","天候コード","コース","レース脚質","単勝","複勝","本賞金","収得賞金","レースペース流れ","馬ペース流れ","４角コース取り","予備"]         

                # df = pd.read_fwf(filename,colspecs=colspecs,names=names,converters={'key':np.str},encoding="cp932")
                df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
                df_all = pd.concat([df, df_all], axis = 0)
                print(l)
              
            except:
                pass

# df = pd.read_csv(BytesIO(data))
df_all.shape
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:741: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# SED170105
# SED170107
# SED170108
# SED170114
# SED170115
# SED170116
# SED170117
# SED170121
# SED170122
# SED170128
# SED170129
# SED170204
# SED170205
# SED170211
# SED170212
# SED170213
# SED170218
# SED170219
# SED170225
# SED170226
# SED170304
# SED170305
# SED170311
# SED170312
# SED170318
# SED170319
# SED170320
# SED170325
# SED170326
# SED170401
# SED170402
# SED170408
# SED170409
# SED170415
# SED170416
# SED170422
# SED170423
# SED170429
# SED170430
# SED170506
# SED170507
# SED170513
# SED170514
# SED170520
# SED170521
# SED170527
# SED170528
# SED170603
# SED170604
# SED170610
# SED170611
# SED170617
# SED170618
# SED170624
# SED170625
# SED170701
# SED170702
# SED170708
# SED170709
# SED170715
# SED170716
# SED170722
# SED170723
# SED170729
# SED170730
# ...

# %%
df_all.to_csv("df_SED_all.csv")

# %%
df_all = pd.read_csv("df_SED_all.csv")
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,29,31,32,33,34,49,50,51,52,54,55,60,61,66,67,72,73,74,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_all["異常区分"].value_counts().values
# Out:
# array([124092,    582,    246,    223,     34,     29,     25,     18,
#            17,     16])

# %%
df_all["タイム"].value_counts()
# Out:
# 0.0       952
# 1099.0    448
# 1121.0    448
# 1095.0    441
# 1123.0    437
# 1130.0    436
# 1097.0    434
# 1101.0    427
# 1126.0    423
# 1131.0    420
# 1093.0    409
# 1119.0    407
# 1096.0    407
# 1122.0    405
# 1124.0    403
# 1129.0    397
# 1127.0    396
# 1128.0    395
# 1106.0    393
# 1100.0    392
# 1103.0    392
# 1118.0    390
# 1134.0    389
# 1104.0    388
# 1098.0    383
# 1094.0    382
# 1117.0    381
# 1132.0    379
# 1133.0    377
# 1091.0    377
#          ...
# 4309.0      1
# 4456.0      1
# 4479.0      1
# 4475.0      1
# 4428.0      1
# 2508.0      1
# 1043.0      1
# 3488.0      1
# 4564.0      1
# 4531.0      1
# 2486.0      1
# 200.0       1
# 4516.0      1
# 4281.0      1
# 3506.0      1
# 4454.0      1
# 3346.0      1
# 4527.0      1
# 4430.0      1
# 3499.0      1
# 4020.0      1
# 4314.0      1
# 4517.0      1
# 2590.0      1
# 4450.0      1
# 3491.0      1
# 4514.0      1
# 2539.0      1
# 4511.0      1
# 1038.0      1
# ...

# %% [markdown]
# # データセット随時作成

# %%
df_all = pd.DataFrame()
for i in range(18, 19):
    for j in range(8, 13):
        for k in range(1,32):
            try:
                
                l = "KYI" + str(i) + str(j).zfill(2) + str(k).zfill(2) + ".txt"

                filename = './' + l

                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,10),(10,18),(18,36),(36,41),(41,46),(46,51),(51,56),(56,61),(61,66),(66,71),(71,72),(72,73),(73,74),(74,77),(77,82),(82,84),(84,89),(89,91),(91,94),(94,97),(97,100),(100,103),(103,106),(106,109),(109,112),(112,115),(115,118),(118,121),(121,126),(126,131),(131,136),(136,137),(137,138),(138,142),(142,145),(145,147),(147,148),(148,150),(150,152),(152,153),(153,159),(159,162),(162,163),(163,169),(169,171),(171,187),(187,203),(203,219),(219,235),(235,251),(251,259),(259,267),(267,275),(275,283),(283,291),(291,292),(292,294),(294,295),(295,296),(296,297),(297,298),(298,299),(299,300),(300,301),(301,302),(302,303),(303,308),(308,313),(313,314),(314,320),(320,325),(325,326),(326,331),(331,336),(336,341),(341,346),(346,347),(347,349),(349,351),(351,352),(352,354),(354,356),(356,357),(357,359),(359,361),(361,362),(362,363),(363,364),(364,367),(367,370),(370,371),(371,372),(372,392),(392,394),(394,396),(396,398),(398,400),(400,402),(402,404),(404,406),(406,408),(408,412),(412,416),(416,417),(417,425),(425,449),(449,452),(452,455),(455,458),(458,461),(461,464),(464,467),(467,471),(471,475),(475,477),(477,482),(482,485),(485,486),(486,487),(487,489),(489,491),(491,507),(507,509),(509,517),(517,520),(520,545),(545,546),(546,547),(547,945),(945,947)]

                #ファイルを区切った際のカラム名
                names = ['年','回','日','Ｒ','馬番','血統登録番号','馬名','ＩＤＭ','騎手指数','情報指数','予備１','予備２','予備３','総合指数','脚質','距離適性','上昇度','ローテーション','基準オッズ','基準人気順位','基準複勝オッズ','基準複勝人気順位','特定情報◎','特定情報○','特定情報▲','特定情報△','特定情報×','総合情報◎','総合情報○','総合情報▲','総合情報△','総合情報×','人気指数','調教指数','厩舎指数','調教矢印コード','厩舎評価コード','騎手期待連対率','激走指数','蹄コード','重適正コード','クラスコード','予備','ブリンカー','騎手名','負担重量','見習い区分','調教師名','調教師所属','前走１競走成績キー','前走２競走成績キー','前走３競走成績キー','前走４競走成績キー','前走５競走成績キー','前走１レースキー','前走２レースキー','前走３レースキー','前走４レースキー','前走５レースキー','枠番','予備','総合印','ＩＤＭ印','情報印','騎手印','厩舎印','調教印','激走印','芝適性コード','ダ適性コード','騎手コード','調教師コード','予備','獲得賞金','収得賞金','条件クラス','テン指数','ペース指数','上がり指数','位置指数','ペース予想','道中順位','道中差','道中内外','後３Ｆ順位','後３Ｆ差','後３Ｆ内外','ゴール順位','ゴール差','ゴール内外','展開記号','距離適性２','枠確定馬体重','枠確定馬体重増減','取消フラグ','性別コード','馬主名','馬主会コード','馬記号コード','激走順位','LS指数順位','テン指数順位','ペース指数順位','上がり指数順位','位置指数順位','騎手期待単勝率','騎手期待３着内率','輸送区分','走法','体型','体型総合１','体型総合２','体型総合３','馬特記１','馬特記２','馬特記３','馬スタート指数','馬出遅率','参考前走','参考前走騎手コード','万券指数','万券印','降級フラグ','激走タイプ','休養理由分類コード','フラグ','入厩何走目','入厩年月日','入厩何日前','放牧先','放牧先ランク','厩舎ランク','予備','予備']         

                # df = pd.read_fwf(filename,colspecs=colspecs,names=names,converters={'key':np.str},encoding="cp932")
                df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
                df_all = pd.concat([df, df_all], axis = 0)
                print(l)
              
            except:
                pass

# df = pd.read_csv(BytesIO(data))
df_all.shape
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:741: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# KYI180804.txt
# KYI180805.txt
# (518, 134)

# %%
df_kyi = df_all

# %%
df_kyi = df_kyi.reset_index()
df_kyi.head()
# Out:
#    index   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  ...   \
# 0      4  18  2  4  11   1  15104493  バクハツ　　　　　　　　　　　　　　  43.0   0.1  ...
# 1      4  18  2  4  11   2  15100318  アルクトス　　　　　　　　　　　　　  60.0   0.6  ...
# 2      4  18  2  4  11   3  15104741  イダペガサス　　　　　　　　　　　　  58.0   0.5  ...
# 3      4  18  2  4  11   4  15100995  ドンフォルティス　　　　　　　　　　  63.0   1.7  ...
# 4      4  18  2  4  11   5  15104880  アドマイヤビクター　　　　　　　　　  59.1   1.6  ...
#
#    休養理由分類コード      フラグ  入厩何走目     入厩年月日  入厩何日前                   放牧先  放牧先ランク  \
# 0        NaN   3001.0      3  20180503    NaN  グリーンウッド・トレーニング甲南馬事公苑     NaN
# 1        NaN   3000.0      1  20180718   18.0              ブルーステーブル     NaN
# 2        NaN  13001.0      2  20180516    NaN  ノーザンファーム天栄（旧天栄ホースパーク     NaN
# 3        NaN      9.0      2  20180606    NaN           宇治田原優駿ステーブル     NaN
# 4        NaN   3001.0      3  20180427    NaN          ノーザンファームしがらき     NaN
#
#    厩舎ランク  予備.3  予備.4
# 0    NaN    B6   NaN
# ...

# %%
df_kyi = df_kyi.rename(columns={"index":"場コード"})
df_kyi.head()
# Out:
#    場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0     4  18  2  4  11   1  15104493  バクハツ　　　　　　　　　　　　　　  43.0   0.1
# 1     4  18  2  4  11   2  15100318  アルクトス　　　　　　　　　　　　　  60.0   0.6
# 2     4  18  2  4  11   3  15104741  イダペガサス　　　　　　　　　　　　  58.0   0.5
# 3     4  18  2  4  11   4  15100995  ドンフォルティス　　　　　　　　　　  63.0   1.7
# 4     4  18  2  4  11   5  15104880  アドマイヤビクター　　　　　　　　　  59.1   1.6
#
#       ...          フラグ  入厩何走目     入厩年月日  入厩何日前                   放牧先  放牧先ランク  \
# 0     ...       3001.0      3  20180503    NaN  グリーンウッド・トレーニング甲南馬事公苑     NaN
# 1     ...       3000.0      1  20180718   18.0              ブルーステーブル     NaN
# 2     ...      13001.0      2  20180516    NaN  ノーザンファーム天栄（旧天栄ホースパーク     NaN
# 3     ...          9.0      2  20180606    NaN           宇治田原優駿ステーブル     NaN
# 4     ...       3001.0      3  20180427    NaN          ノーザンファームしがらき     NaN
#
#    厩舎ランク  予備.3  予備.4        結果キー
# 0    NaN    B6   NaN  0418241101
# ...

# %%
df_kyi["結果キー"] = df_kyi["場コード"].apply(lambda x: str(x).zfill(2)) + df_kyi["年"].apply(lambda x: str(x).zfill(2)) + df_kyi["回"].astype(str)+ df_kyi["日"].astype(str)+ df_kyi["Ｒ"].apply(lambda x: str(x).zfill(2))+ df_kyi["馬番"].apply(lambda x: str(x).zfill(2))

# %%
names = ["結果場コード","結果年","結果回","結果日","結果Ｒ","結果馬番","結果血統登録番号","結果年月日","結果馬名","結果距離","結果芝ダ障害コード","結果右左","結果内外","結果馬場状態","結果種別","結果条件","結果記号","結果重量","結果グレード","結果レース名","結果頭数","結果レース名略称","結果着順","結果異常区分","結果タイム","結果斤量","結果騎手名","結果調教師名","結果確定単勝オッズ","結果確定単勝人気順位","結果ＩＤＭ","結果素点","結果馬場差","結果ペース","結果出遅","結果位置取","結果不利","結果前不利","結果中不利","結果後不利","結果レース","結果コース取り","結果上昇度コード","結果クラスコード","結果馬体コード","結果気配コード","結果レースペース","結果馬ペース","結果テン指数","結果上がり指数","結果ペース指数","結果レースＰ指数","結果1(2)着馬名","結果1(2)着タイム差","結果前３Ｆタイム","結果後３Ｆタイム","結果備考","結果予備","結果確定複勝オッズ下","結果10時単勝オッズ","結果10時複勝オッズ","結果コーナー順位１","結果コーナー順位２","結果コーナー順位３","結果コーナー順位４","結果前３Ｆ先頭差","結果後３Ｆ先頭差","結果騎手コード","結果調教師コード","結果馬体重","結果馬体重増減","結果天候コード","結果コース","結果レース脚質","結果単勝","結果複勝","結果本賞金","結果収得賞金","結果レースペース流れ","結果馬ペース流れ","結果４角コース取り","結果予備"]
df_sed = pd.read_csv("df_SED_all2.csv", index_col=0, names=names,skiprows=1)
df_sed["結果キー"] = df_sed["結果場コード"].apply(lambda x: str(x).zfill(2))  + df_sed["結果年"].apply(lambda x: str(x).zfill(2))+ df_sed["結果回"].astype(str)+ df_sed["結果日"].astype(str)+ df_sed["結果Ｒ"].apply(lambda x: str(x).zfill(2))+ df_sed["結果馬番"].apply(lambda x: str(x).zfill(2))
df_all = pd.merge(df_kyi, df_sed, how="left", on="結果キー")
df_sed.head()
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,54,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    結果場コード  結果年  結果回 結果日  結果Ｒ  結果馬番  結果血統登録番号     結果年月日                結果馬名  \
# 0       2   18    2   4    1     1  16106369  20180715  ラッキーロード
# 1       2   18    2   4    1     2  16104201  20180715  カガストロング
# 2       2   18    2   4    1     3  16102434  20180715  ロードワンダー
# 3       2   18    2   4    1     4  16100943  20180715  シェルトファータ
# 4       2   18    2   4    1     5  16109057  20180715  ウインベッスル
#
#    結果距離     ...      結果レース脚質   結果単勝   結果複勝  結果本賞金  結果収得賞金 結果レースペース流れ  \
# ...

# %%
names = ["1走前_場コード","1走前_年","1走前_回","1走前_日","1走前_Ｒ","1走前_馬番","1走前_血統登録番号","1走前_年月日","1走前_馬名","1走前_距離","1走前_芝ダ障害コード","1走前_右左","1走前_内外","1走前_馬場状態","1走前_種別","1走前_条件","1走前_記号","1走前_重量","1走前_グレード","1走前_レース名","1走前_頭数","1走前_レース名略称","1走前_着順","1走前_異常区分","1走前_タイム","1走前_斤量","1走前_騎手名","1走前_調教師名","1走前_確定単勝オッズ","1走前_確定単勝人気順位","1走前_ＩＤＭ","1走前_素点","1走前_馬場差","1走前_ペース","1走前_出遅","1走前_位置取","1走前_不利","1走前_前不利","1走前_中不利","1走前_後不利","1走前_レース","1走前_コース取り","1走前_上昇度コード","1走前_クラスコード","1走前_馬体コード","1走前_気配コード","1走前_レースペース","1走前_馬ペース","1走前_テン指数","1走前_上がり指数","1走前_ペース指数","1走前_レースＰ指数","1走前_1(2)着馬名","1走前_1(2)着タイム差","1走前_前３Ｆタイム","1走前_後３Ｆタイム","1走前_備考","1走前_予備","1走前_確定複勝オッズ下","1走前_10時単勝オッズ","1走前_10時複勝オッズ","1走前_コーナー順位１","1走前_コーナー順位２","1走前_コーナー順位３","1走前_コーナー順位４","1走前_前３Ｆ先頭差","1走前_後３Ｆ先頭差","1走前_騎手コード","1走前_調教師コード","1走前_馬体重","1走前_馬体重増減","1走前_天候コード","1走前_コース","1走前_レース脚質","1走前_単勝","1走前_複勝","1走前_本賞金","1走前_収得賞金","1走前_レースペース流れ","1走前_馬ペース流れ","1走前_４角コース取り","1走前_予備"]
df_sed = pd.read_csv("df_SED_all2.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
# 後者だけ桁あわせする
df_sed["前走１競走成績キー"] = (df_sed["1走前_血統登録番号"].astype(str) + df_sed["1走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走１競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,54,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       4  18  2  4  11   1  15104493  バクハツ　　　　　　　　　　　　　　  43.0   0.1
# 1       4  18  2  4  11   2  15100318  アルクトス　　　　　　　　　　　　　  60.0   0.6
# 2       4  18  2  4  11   3  15104741  イダペガサス　　　　　　　　　　　　  58.0   0.5
# 3       4  18  2  4  11   4  15100995  ドンフォルティス　　　　　　　　　　  63.0   1.7
# 4       4  18  2  4  11   5  15104880  アドマイヤビクター　　　　　　　　　  59.1   1.6
# ...

# %%
names = ["2走前_場コード","2走前_年","2走前_回","2走前_日","2走前_Ｒ","2走前_馬番","2走前_血統登録番号","2走前_年月日","2走前_馬名","2走前_距離","2走前_芝ダ障害コード","2走前_右左","2走前_内外","2走前_馬場状態","2走前_種別","2走前_条件","2走前_記号","2走前_重量","2走前_グレード","2走前_レース名","2走前_頭数","2走前_レース名略称","2走前_着順","2走前_異常区分","2走前_タイム","2走前_斤量","2走前_騎手名","2走前_調教師名","2走前_確定単勝オッズ","2走前_確定単勝人気順位","2走前_ＩＤＭ","2走前_素点","2走前_馬場差","2走前_ペース","2走前_出遅","2走前_位置取","2走前_不利","2走前_前不利","2走前_中不利","2走前_後不利","2走前_レース","2走前_コース取り","2走前_上昇度コード","2走前_クラスコード","2走前_馬体コード","2走前_気配コード","2走前_レースペース","2走前_馬ペース","2走前_テン指数","2走前_上がり指数","2走前_ペース指数","2走前_レースＰ指数","2走前_1(2)着馬名","2走前_1(2)着タイム差","2走前_前３Ｆタイム","2走前_後３Ｆタイム","2走前_備考","2走前_予備","2走前_確定複勝オッズ下","2走前_10時単勝オッズ","2走前_10時複勝オッズ","2走前_コーナー順位１","2走前_コーナー順位２","2走前_コーナー順位３","2走前_コーナー順位４","2走前_前３Ｆ先頭差","2走前_後３Ｆ先頭差","2走前_騎手コード","2走前_調教師コード","2走前_馬体重","2走前_馬体重増減","2走前_天候コード","2走前_コース","2走前_レース脚質","2走前_単勝","2走前_複勝","2走前_本賞金","2走前_収得賞金","2走前_レースペース流れ","2走前_馬ペース流れ","2走前_４角コース取り","2走前_予備"]
df_sed = pd.read_csv("df_SED_all2.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
df_sed["前走２競走成績キー"] = (df_sed["2走前_血統登録番号"].astype(str) + df_sed["2走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走２競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,54,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       4  18  2  4  11   1  15104493  バクハツ　　　　　　　　　　　　　　  43.0   0.1
# 1       4  18  2  4  11   2  15100318  アルクトス　　　　　　　　　　　　　  60.0   0.6
# 2       4  18  2  4  11   3  15104741  イダペガサス　　　　　　　　　　　　  58.0   0.5
# 3       4  18  2  4  11   4  15100995  ドンフォルティス　　　　　　　　　　  63.0   1.7
# 4       4  18  2  4  11   5  15104880  アドマイヤビクター　　　　　　　　　  59.1   1.6
# ...

# %%
names = ["3走前_場コード","3走前_年","3走前_回","3走前_日","3走前_Ｒ","3走前_馬番","3走前_血統登録番号","3走前_年月日","3走前_馬名","3走前_距離","3走前_芝ダ障害コード","3走前_右左","3走前_内外","3走前_馬場状態","3走前_種別","3走前_条件","3走前_記号","3走前_重量","3走前_グレード","3走前_レース名","3走前_頭数","3走前_レース名略称","3走前_着順","3走前_異常区分","3走前_タイム","3走前_斤量","3走前_騎手名","3走前_調教師名","3走前_確定単勝オッズ","3走前_確定単勝人気順位","3走前_ＩＤＭ","3走前_素点","3走前_馬場差","3走前_ペース","3走前_出遅","3走前_位置取","3走前_不利","3走前_前不利","3走前_中不利","3走前_後不利","3走前_レース","3走前_コース取り","3走前_上昇度コード","3走前_クラスコード","3走前_馬体コード","3走前_気配コード","3走前_レースペース","3走前_馬ペース","3走前_テン指数","3走前_上がり指数","3走前_ペース指数","3走前_レースＰ指数","3走前_1(2)着馬名","3走前_1(2)着タイム差","3走前_前３Ｆタイム","3走前_後３Ｆタイム","3走前_備考","3走前_予備","3走前_確定複勝オッズ下","3走前_10時単勝オッズ","3走前_10時複勝オッズ","3走前_コーナー順位１","3走前_コーナー順位２","3走前_コーナー順位３","3走前_コーナー順位４","3走前_前３Ｆ先頭差","3走前_後３Ｆ先頭差","3走前_騎手コード","3走前_調教師コード","3走前_馬体重","3走前_馬体重増減","3走前_天候コード","3走前_コース","3走前_レース脚質","3走前_単勝","3走前_複勝","3走前_本賞金","3走前_収得賞金","3走前_レースペース流れ","3走前_馬ペース流れ","3走前_４角コース取り","3走前_予備"]
df_sed = pd.read_csv("df_SED_all2.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
df_sed["前走３競走成績キー"] = (df_sed["3走前_血統登録番号"].astype(str) + df_sed["3走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走３競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,54,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       4  18  2  4  11   1  15104493  バクハツ　　　　　　　　　　　　　　  43.0   0.1
# 1       4  18  2  4  11   2  15100318  アルクトス　　　　　　　　　　　　　  60.0   0.6
# 2       4  18  2  4  11   3  15104741  イダペガサス　　　　　　　　　　　　  58.0   0.5
# 3       4  18  2  4  11   4  15100995  ドンフォルティス　　　　　　　　　　  63.0   1.7
# 4       4  18  2  4  11   5  15104880  アドマイヤビクター　　　　　　　　　  59.1   1.6
# ...

# %%
names = ["4走前_場コード","4走前_年","4走前_回","4走前_日","4走前_Ｒ","4走前_馬番","4走前_血統登録番号","4走前_年月日","4走前_馬名","4走前_距離","4走前_芝ダ障害コード","4走前_右左","4走前_内外","4走前_馬場状態","4走前_種別","4走前_条件","4走前_記号","4走前_重量","4走前_グレード","4走前_レース名","4走前_頭数","4走前_レース名略称","4走前_着順","4走前_異常区分","4走前_タイム","4走前_斤量","4走前_騎手名","4走前_調教師名","4走前_確定単勝オッズ","4走前_確定単勝人気順位","4走前_ＩＤＭ","4走前_素点","4走前_馬場差","4走前_ペース","4走前_出遅","4走前_位置取","4走前_不利","4走前_前不利","4走前_中不利","4走前_後不利","4走前_レース","4走前_コース取り","4走前_上昇度コード","4走前_クラスコード","4走前_馬体コード","4走前_気配コード","4走前_レースペース","4走前_馬ペース","4走前_テン指数","4走前_上がり指数","4走前_ペース指数","4走前_レースＰ指数","4走前_1(2)着馬名","4走前_1(2)着タイム差","4走前_前３Ｆタイム","4走前_後３Ｆタイム","4走前_備考","4走前_予備","4走前_確定複勝オッズ下","4走前_10時単勝オッズ","4走前_10時複勝オッズ","4走前_コーナー順位１","4走前_コーナー順位２","4走前_コーナー順位３","4走前_コーナー順位４","4走前_前３Ｆ先頭差","4走前_後３Ｆ先頭差","4走前_騎手コード","4走前_調教師コード","4走前_馬体重","4走前_馬体重増減","4走前_天候コード","4走前_コース","4走前_レース脚質","4走前_単勝","4走前_複勝","4走前_本賞金","4走前_収得賞金","4走前_レースペース流れ","4走前_馬ペース流れ","4走前_４角コース取り","4走前_予備"]
df_sed = pd.read_csv("df_SED_all2.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
df_sed["前走４競走成績キー"] = (df_sed["4走前_血統登録番号"].astype(str) + df_sed["4走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走４競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,54,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       4  18  2  4  11   1  15104493  バクハツ　　　　　　　　　　　　　　  43.0   0.1
# 1       4  18  2  4  11   2  15100318  アルクトス　　　　　　　　　　　　　  60.0   0.6
# 2       4  18  2  4  11   3  15104741  イダペガサス　　　　　　　　　　　　  58.0   0.5
# 3       4  18  2  4  11   4  15100995  ドンフォルティス　　　　　　　　　　  63.0   1.7
# 4       4  18  2  4  11   5  15104880  アドマイヤビクター　　　　　　　　　  59.1   1.6
# ...

# %%
names = ["5走前_場コード","5走前_年","5走前_回","5走前_日","5走前_Ｒ","5走前_馬番","5走前_血統登録番号","5走前_年月日","5走前_馬名","5走前_距離","5走前_芝ダ障害コード","5走前_右左","5走前_内外","5走前_馬場状態","5走前_種別","5走前_条件","5走前_記号","5走前_重量","5走前_グレード","5走前_レース名","5走前_頭数","5走前_レース名略称","5走前_着順","5走前_異常区分","5走前_タイム","5走前_斤量","5走前_騎手名","5走前_調教師名","5走前_確定単勝オッズ","5走前_確定単勝人気順位","5走前_ＩＤＭ","5走前_素点","5走前_馬場差","5走前_ペース","5走前_出遅","5走前_位置取","5走前_不利","5走前_前不利","5走前_中不利","5走前_後不利","5走前_レース","5走前_コース取り","5走前_上昇度コード","5走前_クラスコード","5走前_馬体コード","5走前_気配コード","5走前_レースペース","5走前_馬ペース","5走前_テン指数","5走前_上がり指数","5走前_ペース指数","5走前_レースＰ指数","5走前_1(2)着馬名","5走前_1(2)着タイム差","5走前_前３Ｆタイム","5走前_後３Ｆタイム","5走前_備考","5走前_予備","5走前_確定複勝オッズ下","5走前_10時単勝オッズ","5走前_10時複勝オッズ","5走前_コーナー順位１","5走前_コーナー順位２","5走前_コーナー順位３","5走前_コーナー順位４","5走前_前３Ｆ先頭差","5走前_後３Ｆ先頭差","5走前_騎手コード","5走前_調教師コード","5走前_馬体重","5走前_馬体重増減","5走前_天候コード","5走前_コース","5走前_レース脚質","5走前_単勝","5走前_複勝","5走前_本賞金","5走前_収得賞金","5走前_レースペース流れ","5走前_馬ペース流れ","5走前_４角コース取り","5走前_予備"]
df_sed = pd.read_csv("df_SED_all2.csv", index_col=0, names=names,skiprows=1)
# df_all["前走１競走成績キー"] = df_all["前走１競走成績キー"].astype(str)
df_sed["前走５競走成績キー"] = (df_sed["5走前_血統登録番号"].astype(str) + df_sed["5走前_年月日"].apply(lambda x: str(x).zfill(8))).astype(int)
df_all = pd.merge(df_all, df_sed, how="left", on="前走５競走成績キー")
df_all
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,54,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数  \
# 0       4  18  2  4  11   1  15104493  バクハツ　　　　　　　　　　　　　　  43.0   0.1
# 1       4  18  2  4  11   2  15100318  アルクトス　　　　　　　　　　　　　  60.0   0.6
# 2       4  18  2  4  11   3  15104741  イダペガサス　　　　　　　　　　　　  58.0   0.5
# 3       4  18  2  4  11   4  15100995  ドンフォルティス　　　　　　　　　　  63.0   1.7
# 4       4  18  2  4  11   5  15104880  アドマイヤビクター　　　　　　　　　  59.1   1.6
# ...

# %%
df_all.to_csv("df_all_yosoku_1808_w1")

# %%
df_all["血統登録番号"]
# Out:
# array(['年', '回', '日', 'Ｒ', '馬番', '血統登録番号', '馬名', 'ＩＤＭ', '騎手指数', '情報指数',
#        '予備１', '予備２', '予備３', '総合指数', '脚質', '距離適性', '上昇度', 'ローテーション',
#        '基準オッズ', '基準人気順位', '基準複勝オッズ', '基準複勝人気順位', '特定情報◎', '特定情報○',
#        '特定情報▲', '特定情報△', '特定情報×', '総合情報◎', '総合情報○', '総合情報▲', '総合情報△',
#        '総合情報×', '人気指数', '調教指数', '厩舎指数', '調教矢印コード', '厩舎評価コード', '騎手期待連対率',
#        '激走指数', '蹄コード', '重適正コード', 'クラスコード', '予備', 'ブリンカー', '騎手名', '負担重量',
#        '見習い区分', '調教師名', '調教師所属', '前走１競走成績キー', '前走２競走成績キー', '前走３競走成績キー',
#        '前走４競走成績キー', '前走５競走成績キー', '前走１レースキー', '前走２レースキー', '前走３レースキー',
#        '前走４レースキー', '前走５レースキー', '枠番', '予備.1', '総合印', 'ＩＤＭ印', '情報印', '騎手印',
#        '厩舎印', '調教印', '激走印', '芝適性コード', 'ダ適性コード', '騎手コード', '調教師コード', '予備.2',
#        '獲得賞金', '収得賞金', '条件クラス', 'テン指数', 'ペース指数', '上がり指数', '位置指数', 'ペース予想',
#        '道中順位', '道中差', '道中内外', '後３Ｆ順位', '後３Ｆ差', '後３Ｆ内外', 'ゴール順位', 'ゴール差',
#        'ゴール内外', '展開記号', '距離適性２', '枠確定馬体重', '枠確定馬体重増減', '取消フラグ', '性別コード',
# ...

# %% [markdown]
# # BACデータセット作成

# %%
df_all = pd.DataFrame()
for i in range(17, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                
                l = "BAC" + str(i) + str(j).zfill(2) + str(k).zfill(2) + ".txt"

                filename = './BAC/' + l

                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,16),(16,20),(20,24),(24,25),(25,26),(26,27),(27,29),(29,31),(31,34),(34,35),(35,36),(36,61)]

                #ファイルを区切った際のカラム名
                names = ["場コード","年","回","日","Ｒ","年月日","発走時間","距離","芝ダ障害コード","右左","内外","種別","条件","記号","重量","グレード","レース名"] 
                
                # df = pd.read_fwf(filename,colspecs=colspecs,names=names,converters={'key':np.str},encoding="cp932")
                df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
                df_all = pd.concat([df, df_all], axis = 0)
                print(l)
              
            except:
                pass

# df = pd.read_csv(BytesIO(data))
df_all.shape
# Out:
# BAC170105.txt
# BAC170107.txt
# BAC170108.txt
# BAC170114.txt
# BAC170115.txt
# BAC170116.txt
# BAC170117.txt
# BAC170121.txt
# BAC170122.txt
# BAC170128.txt
# BAC170129.txt
# BAC170204.txt
# BAC170205.txt
# BAC170211.txt
# BAC170212.txt
# BAC170213.txt
# BAC170218.txt
# BAC170219.txt
# BAC170225.txt
# BAC170226.txt
# BAC170304.txt
# BAC170305.txt
# BAC170311.txt
# BAC170312.txt
# BAC170318.txt
# BAC170319.txt
# BAC170320.txt
# BAC170325.txt
# BAC170326.txt
# BAC170401.txt
# BAC170402.txt
# BAC170408.txt
# BAC170409.txt
# BAC170415.txt
# BAC170416.txt
# BAC170422.txt
# BAC170423.txt
# BAC170429.txt
# BAC170430.txt
# BAC170506.txt
# BAC170507.txt
# BAC170513.txt
# BAC170514.txt
# BAC170520.txt
# BAC170521.txt
# BAC170527.txt
# BAC170528.txt
# BAC170603.txt
# BAC170604.txt
# BAC170610.txt
# BAC170611.txt
# BAC170617.txt
# BAC170618.txt
# BAC170624.txt
# BAC170625.txt
# BAC170701.txt
# BAC170702.txt
# BAC170708.txt
# BAC170709.txt
# BAC170715.txt
# BAC170716.txt
# BAC170722.txt
# ...

# %%
for i in range(8, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                
                l = "BAC" + str(i).zfill(2) + str(j).zfill(2) + str(k).zfill(2) + ".txt"

                filename = './BAC/BAC_20' + str(i).zfill(2) + '/' + l

                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,16),(16,20),(20,24),(24,25),(25,26),(26,27),(27,29),(29,31),(31,34),(34,35),(35,36),(36,61)]

                #ファイルを区切った際のカラム名
                names = ["場コード","年","回","日","Ｒ","年月日","発走時間","距離","芝ダ障害コード","右左","内外","種別","条件","記号","重量","グレード","レース名"] 
                
                # df = pd.read_fwf(filename,colspecs=colspecs,names=names,converters={'key':np.str},encoding="cp932")
                df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
                df_all = pd.concat([df, df_all], axis = 0)
                print(l)
              
            except:
                pass

# df = pd.read_csv(BytesIO(data))
df_all.shape
# Out:
# BAC080105.txt
# BAC080106.txt
# BAC080112.txt
# BAC080113.txt
# BAC080119.txt
# BAC080120.txt
# BAC080126.txt
# BAC080127.txt
# BAC080202.txt
# BAC080203.txt
# BAC080204.txt
# BAC080209.txt
# BAC080210.txt
# BAC080211.txt
# BAC080216.txt
# BAC080217.txt
# BAC080223.txt
# BAC080224.txt
# BAC080301.txt
# BAC080302.txt
# BAC080308.txt
# BAC080309.txt
# BAC080315.txt
# BAC080316.txt
# BAC080322.txt
# BAC080323.txt
# BAC080329.txt
# BAC080330.txt
# BAC080405.txt
# BAC080406.txt
# BAC080412.txt
# BAC080413.txt
# BAC080419.txt
# BAC080420.txt
# BAC080426.txt
# BAC080427.txt
# BAC080503.txt
# BAC080504.txt
# BAC080510.txt
# BAC080511.txt
# BAC080517.txt
# BAC080518.txt
# BAC080524.txt
# BAC080525.txt
# BAC080531.txt
# BAC080601.txt
# BAC080607.txt
# BAC080608.txt
# BAC080614.txt
# BAC080615.txt
# BAC080621.txt
# BAC080622.txt
# BAC080628.txt
# BAC080629.txt
# BAC080705.txt
# BAC080706.txt
# BAC080712.txt
# BAC080713.txt
# BAC080719.txt
# BAC080720.txt
# BAC080726.txt
# BAC080727.txt
# ...

# %%
df_BAC = pd.DataFrame()
for i in range(18, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                l = "BAC" + str(i).zfill(2) + str(j).zfill(2) + str(k).zfill(2) + ".txt"
                date_test = str(i) + str(j).zfill(2) + str(k).zfill(2)

                filename = './TEST/PACI' + date_test +'/' + l

#                 filename = './BAC/BAC_20' + str(i).zfill(2) + '/' + l

                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,16),(16,20),(20,24),(24,25),(25,26),(26,27),(27,29),(29,31),(31,34),(34,35),(35,36),(36,61)]

                #ファイルを区切った際のカラム名
                names = ["場コード","年","回","日","Ｒ","年月日","発走時間","距離","芝ダ障害コード","右左","内外","種別","条件","記号","重量","グレード","レース名"] 
                
                # df = pd.read_fwf(filename,colspecs=colspecs,names=names,converters={'key':np.str},encoding="cp932")
                df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
                df_BAC = pd.concat([df, df_BAC], axis = 0)
                print(l)
              
            except:
                pass

# df = pd.read_csv(BytesIO(data))
df_BAC.shape
# Out:
# BAC180825.txt
# BAC180826.txt
# (38, 17)

# %%
df_all["レース名"].value_counts()
# Out:
# フィリーズレビュー       12
# 中山牝馬ステークス       12
# 中京記念            12
# うずしおステークス       12
# 阪神スプリングジャンプ     12
# 江の島特別           11
# 八ヶ岳特別           11
# 万葉ステークス         11
# 苗場特別            11
# 千里山特別           11
# 指宿特別            11
# オーストラリアトロフィー    11
# 巴賞              11
# 早苗賞             11
# スピカステークス        11
# マリーンステークス       11
# マレーシアカップ        11
# フリーウェイステークス     11
# 桜花賞             11
# 難波ステークス         11
# 函館記念            11
# 小倉大賞典           11
# 大阪－ハンブルクカップ     11
# 千葉ステークス         11
# 中京スポーツ杯         11
# 斑鳩ステークス         11
# なにわステークス        11
# 京都ハイジャンプ        11
# 三木特別            11
# オーシャンステークス      11
#                 ..
# 笹山特別             1
# 先斗町特別            1
# 大形特別             1
# 阪神スプリングプレミアム     1
# 瀬田特別             1
# 中京サンクスプレミアム      1
# こけもも賞            1
# 大濠特別             1
# サンクフルハンデキャップ     1
# 東京スマイルプレミアム      1
# 甘木特別             1
# 白根特別             1
# 白老特別             1
# 川中島ステークス         1
# 耶馬渓特別            1
# 鳥海山特別            1
# ...

# %%
df_all.to_csv("df_BAC180804.csv")

# %%
del df_all["Unnamed: 0"]

# %%
df_all = pd.read_csv("df_BAC180804.csv", index_col=0)

# %%
df = pd.DataFrame()
df = df_all
df_all = df_BAC
df.head()
# Out:
#    場コード   年  回  日   Ｒ  馬番    血統登録番号                  馬名   ＩＤＭ  騎手指数    ...     \
# 0     1  18  2  4  11   1  13100389  クリーンファンキー　　　　　　　　　  64.1   0.4    ...
# 1     1  18  2  4  11   2  13105529  スターオブペルシャ　　　　　　　　　  60.0   0.7    ...
# 2     1  18  2  4  11   3  11104627  ヒルノデイバロー　　　　　　　　　　  70.0   0.4    ...
# 3     1  18  2  4  11   4  13104606  ペイシャフェリシタ　　　　　　　　　  62.0   0.3    ...
# 4     1  18  2  4  11   5  13106148  ムーンクエイク　　　　　　　　　　　  68.5   1.6    ...
#
#    5走前_コース  5走前_レース脚質  5走前_単勝  5走前_複勝  5走前_本賞金  5走前_収得賞金  5走前_レースペース流れ  \
# 0        4          2     NaN     170      420         0          11.0
# 1        6          3     NaN     150      460         0          31.0
# 2        1          2     NaN     400      920         0          22.0
# 3        5          3     NaN     140      920         0          22.0
# 4        5          2     150     110     1500       600          31.0
#
#    5走前_馬ペース流れ  5走前_４角コース取り  5走前_予備.1
# 0        11.0          3.0       NaN
# ...

# %%
df = pd.read_csv("df_all_180803.csv", index_col=0)
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,51,56,57,58,59,60,99,112,136,140,190,196,197,222,227,234,238,240,245,246,265,266,271,289,304,386,468,550) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
del df["Unnamed: 0"]

# %%
df_all.columns
# Out:
# Index(['Unnamed: 0', '場コード', '年', '回', '日', 'Ｒ', '年月日', '発走時間', '距離',
#        '芝ダ障害コード', '右左', '内外', '種別', '条件', '記号', '重量', 'グレード', 'レース名'],
#       dtype='object')

# %%
df_all["レースキー"] = df_all["場コード"].apply(lambda x: str(x).zfill(2)) + df_all["年"].apply(lambda x: str(x).zfill(2)) + df_all["回"].astype(str)+ df_all["日"].astype(str)+ df_all["Ｒ"].apply(lambda x: str(x).zfill(2))

# %%
df["レースキー"] = df["場コード"].apply(lambda x: str(x).zfill(2)) + df["年"].apply(lambda x: str(x).zfill(2)) + df["回"].astype(str)+ df["日"].astype(str)+ df["Ｒ"].apply(lambda x: str(x).zfill(2))

# %%
df.columns.values
# Out:
# array(['場コード', '年', '回', '日', 'Ｒ', '馬番', '血統登録番号', '馬名', 'ＩＤＭ', '騎手指数',
#        '情報指数', '予備１', '予備２', '予備３', '総合指数', '脚質', '距離適性', '上昇度',
#        'ローテーション', '基準オッズ', '基準人気順位', '基準複勝オッズ', '基準複勝人気順位', '特定情報◎',
#        '特定情報○', '特定情報▲', '特定情報△', '特定情報×', '総合情報◎', '総合情報○', '総合情報▲',
#        '総合情報△', '総合情報×', '人気指数', '調教指数', '厩舎指数', '調教矢印コード', '厩舎評価コード',
#        '騎手期待連対率', '激走指数', '蹄コード', '重適正コード', 'クラスコード', '予備', 'ブリンカー',
#        '騎手名', '負担重量', '見習い区分', '調教師名', '調教師所属', '前走１競走成績キー', '前走２競走成績キー',
#        '前走３競走成績キー', '前走４競走成績キー', '前走５競走成績キー', '前走１レースキー', '前走２レースキー',
#        '前走３レースキー', '前走４レースキー', '前走５レースキー', '枠番', '予備.1', '総合印', 'ＩＤＭ印',
#        '情報印', '騎手印', '厩舎印', '調教印', '激走印', '芝適性コード', 'ダ適性コード', '騎手コード',
#        '調教師コード', '予備.2', '獲得賞金', '収得賞金', '条件クラス', 'テン指数', 'ペース指数',
#        '上がり指数', '位置指数', 'ペース予想', '道中順位', '道中差', '道中内外', '後３Ｆ順位', '後３Ｆ差',
#        '後３Ｆ内外', 'ゴール順位', 'ゴール差', 'ゴール内外', '展開記号', '距離適性２', '枠確定馬体重',
# ...

# %%
df_all[df_all["レースキー"] == "10112510"]
# Out:
#        Unnamed: 0  場コード   年  回  日   Ｒ       年月日  発走時間    距離  芝ダ障害コード  右左  内外  \
# 20058          21    10  11  2  5  10  20110326  1500  2000        1   1   1
# 20156          33    10  11  2  5  10  20110312  1450  2000        1   1   1
#
#        種別  条件   記号  重量  グレード  レース名     レースキー
# 20058  14  05  100   4   5.0  牧園特別  10112510
# 20156  14  05  100   4   5.0  牧園特別  10112510

# %%
df_key = pd.DataFrame(df_all["レースキー"].value_counts() == 2)
# df_all["レースキー"].value_counts()
# 以下の重複しているキーを片方だけ削除する
# 結果と紐づくようにするために、古いほうを削除して新しい方だけ残しておくような処理にする
# Out:
# 10182903    1
# 04182a11    1
# 10182909    1
# 10182911    1
# 10182902    1
# 01182312    1
# 01182308    1
# 04182910    1
# 01182311    1
# 10182907    1
# 01182301    1
# 04182912    1
# 01182307    1
# 04182907    1
# 01182306    1
# 10182904    1
# 10182910    1
# 01182303    1
# 04182905    1
# 01182305    1
# 04182908    1
# 10182912    1
# 10182906    1
# 10182905    1
# 04182904    1
# 01182309    1
# 04182903    1
# 01182411    1
# 10182901    1
# 10182908    1
# 04182901    1
# 04182909    1
# 04182906    1
# 01182302    1
# 01182310    1
# 04182902    1
# 01182304    1
# 04182911    1
# Name: レースキー, dtype: int64

# %%
df_key = df_key.reset_index()

# %%
df_key2 = df_key[df_key["レースキー"] == True].sort_values(by="index").reset_index().iloc[:,1]

# %%
df_key3 = pd.merge(pd.DataFrame(df_key2), df_all.reset_index(), left_on="index", right_on="レースキー").iloc[1::2,1]

# %%
for i in df_key3.index:
    df_all = df_all.drop(index=df_key3[i])

# %%
df_all.to_csv("df_BAC180809.csv")

# %%
df = pd.read_csv("df_all_180803.csv", index_col=0)
# Out:
# /Users/takumasaito/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,51,56,57,58,59,60,99,112,136,140,190,196,197,222,227,234,238,240,245,246,265,266,271,289,304,386,468,550) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = pd.merge(df, df_all, how="left", on="レースキー")

# %%
df.to_csv("df_all_180809.csv")

# %%
df = pd.read_csv("df_all_180809.csv")

# %%
df.shape
df.to_csv("df_all_180825_predict.csv")

# %%
df["前走２競走成績キー"].value_counts()
# Out:
# 1.610912e+15    1
# 1.310296e+15    1
# 1.310059e+15    1
# 1.110423e+15    1
# 1.510124e+15    1
# 1.310573e+15    1
# 1.510389e+15    1
# 1.210368e+15    1
# 1.610913e+15    1
# 1.510363e+15    1
# 1.510904e+15    1
# 1.410440e+15    1
# 1.210493e+15    1
# 1.410346e+15    1
# 1.310272e+15    1
# 1.610026e+15    1
# 1.310267e+15    1
# 1.510647e+15    1
# 1.310608e+15    1
# 1.511008e+15    1
# 1.410078e+15    1
# 1.610232e+15    1
# 1.510425e+15    1
# 1.610340e+15    1
# 1.310340e+15    1
# 1.610176e+15    1
# 1.510606e+15    1
# 1.510901e+15    1
# 1.310242e+15    1
# 1.510465e+15    1
#                ..
# 1.510359e+15    1
# 1.410081e+15    1
# 1.310186e+15    1
# 1.410248e+15    1
# 1.210439e+15    1
# 1.310268e+15    1
# 1.510500e+15    1
# 1.510035e+15    1
# 1.410331e+15    1
# 1.310432e+15    1
# 1.510035e+15    1
# 1.610382e+15    1
# 1.510337e+15    1
# 1.510479e+15    1
# 1.610405e+15    1
# 1.210460e+15    1
# 1.510186e+15    1
# 1.410623e+15    1
# 1.510465e+15    1
# ...

# %%
df["年月日"].value_counts()
# Out:
# 20180825    494
# 20180826     27
# Name: 年月日, dtype: int64
