# %%
import matplotlib
import numpy as np
import pandas as pd
import sys
# sys.path.append("this\is\the\path")
import urllib.request
from time import sleep

# %%
# for i in range(8, 19):
#     for j in range(1, 13):
#         for k in range(1,32):
#             try:
                
#                 l = "BAC" + str(i).zfill(2) + str(j).zfill(2) + str(k).zfill(2) + ".txt"

#                 filename = './BAC/BAC_20' + str(i).zfill(2) + '/' + l

#                 #ファイルの区切り位置の定義
#                 colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,16),(16,20),(20,24),(24,25),(25,26),(26,27),(27,29),(29,31),(31,34),(34,35),(35,36),(36,61)]

#                 #ファイルを区切った際のカラム名
#                 names = ["場コード","年","回","日","Ｒ","年月日","発走時間","距離","芝ダ障害コード","右左","内外","種別","条件","記号","重量","グレード","レース名"] 
                
#                 # df = pd.read_fwf(filename,colspecs=colspecs,names=names,converters={'key':np.str},encoding="cp932")
#                 df = pd.read_fwf(filename,colspecs=colspecs,names=names,encoding="cp932")
#                 df_all = pd.concat([df, df_all], axis = 0)
#                 print(l)
              
#             except:
#                 pass

# # df = pd.read_csv(BytesIO(data))
# df_all.shape

# %%
i = 18
j = 8
k = 18
l = "OT" + str(i).zfill(2) + str(j).zfill(2) + str(k).zfill(2) + ".txt"

filename = './OT/' + l

#ファイルの区切り位置の定義
colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,10),(10,16),(16,22),(22,28),(28,34),(34,40),(40,46),(46,52),(52,58),(58,64),(64,70),(70,76),(76,82),(82,88),(88,94),(94,100),(100,106),(106,112),(112,118),(118,124),(124,130),(130,136),(136,142),(142,148),(148,154),(154,160),(160,166),(166,172),(172,178),(178,184),(184,190),(190,196),(196,202),(202,208),(208,214),(214,220),(220,226),(226,232),(232,238),(238,244),(244,250),(250,256),(256,262),(262,268),(268,274),(274,280),(280,286),(286,292),(292,298),(298,304),(304,310),(310,316),(316,322),(322,328),(328,334),(334,340),(340,346),(346,352),(352,358),(358,364),(364,370),(370,376),(376,382),(382,388),(388,394),(394,400),(400,406),(406,412),(412,418),(418,424),(424,430),(430,436),(436,442),(442,448),(448,454),(454,460),(460,466),(466,472),(472,478),(478,484),(484,490),(490,496),(496,502),(502,508),(508,514),(514,520),(520,526),(526,532),(532,538),(538,544),(544,550),(550,556),(556,562),(562,568),(568,574),(574,580),(580,586),(586,592),(592,598),(598,604),(604,610),(610,616),(616,622),(622,628),(628,634),(634,640),(640,646),(646,652),(652,658),(658,664),(664,670),(670,676),(676,682),(682,688),(688,694),(694,700),(700,706),(706,712),(712,718),(718,724),(724,730),(730,736),(736,742),(742,748),(748,754),(754,760),(760,766),(766,772),(772,778),(778,784),(784,790),(790,796),(796,802),(802,808),(808,814),(814,820),(820,826),(826,832),(832,838),(838,844),(844,850),(850,856),(856,862),(862,868),(868,874),(874,880),(880,886),(886,892),(892,898),(898,904),(904,910),(910,916),(916,922),(922,928),(928,934),(934,940),(940,946),(946,952),(952,958),(958,964),(964,970),(970,976),(976,982),(982,988),(988,994),(994,1000),(1000,1006),(1006,1012),(1012,1018),(1018,1024),(1024,1030),(1030,1036),(1036,1042),(1042,1048),(1048,1054),(1054,1060),(1060,1066),(1066,1072),(1072,1078),(1078,1084),(1084,1090),(1090,1096),(1096,1102),(1102,1108),(1108,1114),(1114,1120),(1120,1126),(1126,1132),(1132,1138),(1138,1144),(1144,1150),(1150,1156),(1156,1162),(1162,1168),(1168,1174
# 8      1  18  2  1   9    13   389.8   265.6   679.7  1971.3 ...     NaN
# 9      1  18  2  1  10    11   262.6   791.6  1435.6   509.3 ...     NaN
# 10     1  18  2  1  11    11  1244.6   376.7  2371.9   175.3 ...     NaN
# 11     1  18  2  1  12    13  1550.8   631.9   675.8  1255.5 ...     NaN
# ...

# %%
i = 1
df_odds_3renp = pd.DataFrame()
for j in range(1,19):
    for k in range(1,19):
        if k <= j:
            pass
        else:
            for l in range(1,19):
                if l <= k:
                    pass
                else:
                    df_temp = df.iloc[:, [0,1,2,3,4,5,i + 5]]
                    df_temp = df_temp.rename(columns={str(i):"odds"})
                    df_temp["馬番1"] = j
                    df_temp["馬番2"] = k
                    df_temp["馬番3"] = l
                    i = i + 1
                    df_odds_3renp = pd.concat([df_odds_3renp, df_temp])

# %%
df_odds_3renp[(df_odds_3renp["場コード"] == 1) & (df_odds_3renp["Ｒ"] == 1)].dropna()
# Out:
#    場コード   年  回  日  Ｒ  登録頭数   odds  馬番1  馬番2  馬番3
# 0     1  18  2  1  1     7   75.3    1    2    3
# 0     1  18  2  1  1     7  100.0    1    2    4
# 0     1  18  2  1  1     7  860.2    1    2    5
# 0     1  18  2  1  1     7   56.6    1    2    6
# 0     1  18  2  1  1     7  304.5    1    2    7
# 0     1  18  2  1  1     7   43.2    1    3    4
# 0     1  18  2  1  1     7  214.2    1    3    5
# 0     1  18  2  1  1     7   18.1    1    3    6
# 0     1  18  2  1  1     7   64.9    1    3    7
# 0     1  18  2  1  1     7  307.1    1    4    5
# 0     1  18  2  1  1     7   23.8    1    4    6
# 0     1  18  2  1  1     7   79.8    1    4    7
# 0     1  18  2  1  1     7   94.6    1    5    6
# 0     1  18  2  1  1     7  688.1    1    5    7
# 0     1  18  2  1  1     7   52.5    1    6    7
# 0     1  18  2  1  1     7   21.1    2    3    4
# 0     1  18  2  1  1     7   82.7    2    3    5
# 0     1  18  2  1  1     7    9.9    2    3    6
# ...

# %%
# create a password manager
password_mgr = urllib.request.HTTPPasswordMgrWithDefaultRealm()

# Add the username and password.
# If we knew the realm, we could use it instead of None.
username=18075520
password=46027091

top_level_url = "http://www.jrdb.com/member/"
password_mgr.add_password(None, top_level_url, username, password)

handler = urllib.request.HTTPBasicAuthHandler(password_mgr)

# create "opener" (OpenerDirector instance)
opener = urllib.request.build_opener(handler)

# use the opener to fetch a URL
# opener.open("http://www.jrdb.com/member/datazip/Kyi/2018/KYI180722.zip")

# Install the opener.
# Now all calls to urllib.request.urlopen use our opener.
urllib.request.install_opener(opener)

# %%
#URLと保存パスを指定
for i in range(8, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                l = "OT" + str(i).zfill(2) + str(j).zfill(2) + str(k).zfill(2) 
                print(l)
                
                url = "http://www.jrdb.com/member/datazip/Ot/20" + str(i).zfill(2) + "/" + l + ".zip"
                savename = "./OT/" + l  + ".zip"
                
                #ダウンロード --- （＊１）
                nem = urllib.request.urlopen(url).read()

                #ファイルへ保存 --- （＊２）
                with open(savename, mode="wb") as f:
                    f.write(nem)
                    print("保存しました") 
            except:
                pass
            sleep(0.3)
# http://www.jrdb.com/member/datazip/Kyi/2016/KYI160105.zip
# Out:
# OT080101
# OT080102
# OT080103
# OT080104
# OT080105
# 保存しました
# OT080106
# 保存しました
# OT080107
# OT080108
# OT080109
# OT080110
# OT080111
# OT080112
# 保存しました
# OT080113
# 保存しました
# OT080114
# OT080115
# OT080116
# OT080117
# OT080118
# OT080119
# 保存しました
# OT080120
# 保存しました
# OT080121
# OT080122
# OT080123
# OT080124
# OT080125
# OT080126
# 保存しました
# OT080127
# 保存しました
# OT080128
# OT080129
# OT080130
# OT080131
# OT080201
# OT080202
# 保存しました
# OT080203
# 保存しました
# OT080204
# 保存しました
# OT080205
# OT080206
# OT080207
# OT080208
# OT080209
# 保存しました
# OT080210
# 保存しました
# OT080211
# 保存しました
# OT080212
# OT080213
# OT080214
# OT080215
# OT080216
# 保存しました
# OT080217
# 保存しました
# OT080218
# OT080219
# OT080220
# OT080221
# OT080222
# OT080223
# 保存しました
# OT080224
# 保存しました
# OT080225
# OT080226
# OT080227
# OT080228
# OT080229
# OT080230
# OT080231
# OT080301
# 保存しました
# OT080302
# 保存しました
# OT080303
# OT080304
# OT080305
# OT080306
# OT080307
# OT080308
# 保存しました
# OT080309
# 保存しました
# OT080310
# ...

# %%
df_all = pd.DataFrame()
for i in range(8, 19):
    for j in range(1, 13):
        for k in range(1,32):
            try:
                
                l = "OT" + str(i).zfill(2) + str(j).zfill(2) + str(k).zfill(2) + ".txt"

                filename = './OT/' + l

                #ファイルの区切り位置の定義
                colspecs = [(0,2),(2,4),(4,5),(5,6),(6,8),(8,10),(10,16),(16,22),(22,28),(28,34),(34,40),(40,46),(46,52),(52,58),(58,64),(64,70),(70,76),(76,82),(82,88),(88,94),(94,100),(100,106),(106,112),(112,118),(118,124),(124,130),(130,136),(136,142),(142,148),(148,154),(154,160),(160,166),(166,172),(172,178),(178,184),(184,190),(190,196),(196,202),(202,208),(208,214),(214,220),(220,226),(226,232),(232,238),(238,244),(244,250),(250,256),(256,262),(262,268),(268,274),(274,280),(280,286),(286,292),(292,298),(298,304),(304,310),(310,316),(316,322),(322,328),(328,334),(334,340),(340,346),(346,352),(352,358),(358,364),(364,370),(370,376),(376,382),(382,388),(388,394),(394,400),(400,406),(406,412),(412,418),(418,424),(424,430),(430,436),(436,442),(442,448),(448,454),(454,460),(460,466),(466,472),(472,478),(478,484),(484,490),(490,496),(496,502),(502,508),(508,514),(514,520),(520,526),(526,532),(532,538),(538,544),(544,550),(550,556),(556,562),(562,568),(568,574),(574,580),(580,586),(586,592),(592,598),(598,604),(604,610),(610,616),(616,622),(622,628),(628,634),(634,640),(640,646),(646,652),(652,658),(658,664),(664,670),(670,676),(676,682),(682,688),(688,694),(694,700),(700,706),(706,712),(712,718),(718,724),(724,730),(730,736),(736,742),(742,748),(748,754),(754,760),(760,766),(766,772),(772,778),(778,784),(784,790),(790,796),(796,802),(802,808),(808,814),(814,820),(820,826),(826,832),(832,838),(838,844),(844,850),(850,856),(856,862),(862,868),(868,874),(874,880),(880,886),(886,892),(892,898),(898,904),(904,910),(910,916),(916,922),(922,928),(928,934),(934,940),(940,946),(946,952),(952,958),(958,964),
# OT080106.txt
# OT080112.txt
# OT080113.txt
# OT080119.txt
# OT080120.txt
# OT080126.txt
# OT080127.txt
# OT080202.txt
# OT080203.txt
# OT080204.txt
# OT080209.txt
# OT080210.txt
# OT080211.txt
# OT080216.txt
# OT080217.txt
# OT080223.txt
# OT080224.txt
# OT080301.txt
# OT080302.txt
# OT080308.txt
# OT080309.txt
# OT080315.txt
# OT080316.txt
# OT080322.txt
# OT080323.txt
# OT080329.txt
# OT080330.txt
# OT080405.txt
# OT080406.txt
# OT080412.txt
# OT080413.txt
# OT080419.txt
# OT080420.txt
# OT080426.txt
# OT080427.txt
# OT080503.txt
# OT080504.txt
# OT080510.txt
# OT080511.txt
# OT080517.txt
# OT080518.txt
# OT080524.txt
# OT080525.txt
# OT080531.txt
# OT080601.txt
# OT080607.txt
# OT080608.txt
# OT080614.txt
# OT080615.txt
# OT080621.txt
# OT080622.txt
# OT080628.txt
# OT080629.txt
# OT080705.txt
# OT080706.txt
# OT080712.txt
# OT080713.txt
# OT080719.txt
# OT080720.txt
# OT080726.txt
# OT080727.txt
# OT080802.txt
# OT080803.txt
# OT080809.txt
# OT080810.txt
# ...

# %%
i = 1
df_odds_3renp = pd.DataFrame()
for j in range(1,19):
    for k in range(1,19):
        if k <= j:
            pass
        else:
            for l in range(1,19):
                if l <= k:
                    pass
                else:
                    df_temp = df_all.iloc[:, [0,1,2,3,4,5,i + 5]]
                    df_temp = df_temp.rename(columns={str(i):"odds"})
                    df_temp["馬番1"] = j
                    df_temp["馬番2"] = k
                    df_temp["馬番3"] = l
                    i = i + 1
                    df_odds_3renp = pd.concat([df_odds_3renp, df_temp])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-9c03bf37a0fc> in <module>()
#      16                     df_temp["馬番3"] = l
#      17                     i = i + 1
# ---> 18                     df_odds_3renp = pd.concat([df_odds_3renp, df_temp])
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     211                        verify_integrity=verify_integrity,
#     212                        copy=copy)
# --> 213     return op.get_result()
#     214
#     215
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     406             new_data = concatenate_block_managers(
#     407                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# ...

# %%
df_odds_3renp
# Out:
#     場コード   年  回  日   Ｒ  登録頭数    odds  馬番1  馬番2  馬番3
# 0      1  18  2  1   1     7    75.3    1    2    3
# 1      1  18  2  1   2     7   493.2    1    2    3
# 2      1  18  2  1   3    14  9999.8    1    2    3
# 3      1  18  2  1   4    12   107.1    1    2    3
# 4      1  18  2  1   5     8    53.1    1    2    3
# 5      1  18  2  1   6    14    76.1    1    2    3
# 6      1  18  2  1   7    16  9999.8    1    2    3
# 7      1  18  2  1   8    12    70.3    1    2    3
# 8      1  18  2  1   9    13   389.8    1    2    3
# 9      1  18  2  1  10    11   262.6    1    2    3
# 10     1  18  2  1  11    11  1244.6    1    2    3
# 11     1  18  2  1  12    13  1550.8    1    2    3
# 12     4  18  2  7   1    11   153.5    1    2    3
# 13     4  18  2  7   2    14   855.9    1    2    3
# 14     4  18  2  7   3    15  6344.4    1    2    3
# 15     4  18  2  7   4    18  1624.3    1    2    3
# 16     4  18  2  7   5    14    35.6    1    2    3
# ...

# %%
df_all = df_all.reset_index()

# %%
df_all.to_csv("df_OT_180821.csv")

# %%
import gc
gc.collect()
# Out:
# 0
